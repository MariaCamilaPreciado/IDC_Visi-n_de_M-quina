# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import glob
import random
import warnings
warnings.filterwarnings(action = 'ignore')
import matplotlib.pyplot as plt

from PIL import Image

random.seed(98)
np.random.seed(98)

# %%
breast_img = glob.glob('/content/drive/MyDrive/VisiondeMaquina/Entrega/BancoImagenes/Final/**/*.png', recursive = True)

# %%
for imgname in breast_img[:3]:
    print(imgname)
# Out:
# /content/drive/MyDrive/VisiondeMaquina/Entrega/BancoImagenes/Final/0/8951_idx5_x501_y701_class0.png
# /content/drive/MyDrive/VisiondeMaquina/Entrega/BancoImagenes/Final/0/8951_idx5_x601_y1501_class0.png
# /content/drive/MyDrive/VisiondeMaquina/Entrega/BancoImagenes/Final/0/8951_idx5_x551_y1401_class0.png

# %%
non_img = []
can_img = []

for img in breast_img:
    if img[-5] == '0' :
        non_img.append(img)
    
    elif img[-5] == '1' :
        can_img.append(img)

# %%
non_num = len(non_img)
can_num = len(can_img)
        
total_img_num = non_num + can_num
        
print('Number of Images in IDC (-): {}' .format(non_num))
print('Number of Images in IDC (+) : {}' .format(can_num))
print('Total Number of Images : {}' .format(total_img_num))
# Out:
# Number of Images in IDC (-): 7421
# Number of Images in IDC (+) : 5667
# Total Number of Images : 13088

# %%
from keras.preprocessing import image

plt.figure(figsize = (15, 15))

some_non = np.random.randint(0, len(non_img), 18)
some_can = np.random.randint(0, len(can_img), 18)

s = 0
for num in some_non:
    
        img = image.load_img((non_img[num]), target_size=(100, 100))
        img = image.img_to_array(img)
        
        plt.subplot(6, 6, 2*s+1)
        plt.axis('off')
        plt.title('IDC (-)')
        plt.imshow(img.astype('uint8'))
        s += 1
        
s = 1
for num in some_can:
    
        img = image.load_img((can_img[num]), target_size=(100, 100))
        img = image.img_to_array(img)
        
        plt.subplot(6, 6, 2*s)
        plt.axis('off')        
        plt.title('IDC (+)')
        plt.imshow(img.astype('uint8'))
        s += 1

# %%
from matplotlib.image import imread
import cv2

some_non_img = random.sample(non_img, len(can_img))
some_can_img = random.sample(can_img, len(can_img))

non_img_arr = []
can_img_arr = []

for img in some_non_img:
        
    n_img = cv2.imread(img, cv2.IMREAD_COLOR)
    n_img_size = cv2.resize(n_img, (50, 50), interpolation = cv2.INTER_LINEAR)
    non_img_arr.append([n_img_size, 0])
    
for img in some_can_img:
    
    c_img = cv2.imread(img, cv2.IMREAD_COLOR)
    c_img_size = cv2.resize(c_img, (50, 50), interpolation = cv2.INTER_LINEAR)
    can_img_arr.append([c_img_size, 1])

# %%
X = []
y = []

breast_img_arr = np.concatenate((non_img_arr, can_img_arr))
random.shuffle(breast_img_arr)

for feature, label in breast_img_arr:
    X.append(feature)
    y.append(label)
    
X = np.array(X)
y = np.array(y)

print('X shape : {}' .format(X.shape))
# Out:
# X shape : (11334, 50, 50, 3)

# %%
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical

X_train, X_predict, y_train, y_true = train_test_split(X, y, test_size = 0.2, random_state = 7)

rate = 0.5
num = int(X.shape[0] * rate)

X_test = X_train[num:]
X_train = X_train[:num]

y_test = y_train[num:]
y_train = y_train[:num]

y_train = to_categorical(y_train, 2)
y_test = to_categorical(y_test, 2)
y_true = to_categorical(y_true, 2)

print('X_train shape : {}' .format(X_train.shape))
print('X_test shape : {}' .format(X_test.shape))
print('X_predict shape : {}' .format(X_predict.shape))
print('y_train shape : {}' .format(y_train.shape))
print('y_test shape : {}' .format(y_test.shape))
print('y_true shape : {}' .format(y_true.shape))
# Out:
# X_train shape : (5667, 50, 50, 3)
# X_test shape : (3400, 50, 50, 3)
# X_predict shape : (2267, 50, 50, 3)
# y_train shape : (5667, 2)
# y_test shape : (3400, 2)
# y_true shape : (2267, 2)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense

model = Sequential()
model.add(Conv2D(32, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 3)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25)) #

model.add(Conv2D(64, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 3)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 3)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 3)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation = 'relu'))

model.add(Dropout(0.5))
model.add(Dense(2, activation = 'sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 50, 50, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 25, 25, 32)       0
#  )
#
#  dropout (Dropout)           (None, 25, 25, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 25, 25, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 128)         0
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 128)         147584
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 3, 3, 128)         0
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 128)               147584
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 388,674
# Trainable params: 388,674
# Non-trainable params: 0
# _________________________________________________________________

# %%
# !pip install Adam
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Adam in /usr/local/lib/python3.7/dist-packages (0.0.0.dev0)

# %%
from tensorflow.keras.optimizers import Adam

Adam = Adam(learning_rate = 0.0001)
model.compile(loss = 'binary_crossentropy', optimizer = Adam, metrics = ['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = 50, batch_size = 50)
# Out:
# Epoch 1/50
# 114/114 [==============================] - 46s 394ms/step - loss: 6.3033 - accuracy: 0.7810 - val_loss: 0.3875 - val_accuracy: 0.8497
# Epoch 2/50
# 114/114 [==============================] - 43s 373ms/step - loss: 0.9105 - accuracy: 0.7877 - val_loss: 0.6625 - val_accuracy: 0.8491
# Epoch 3/50
# 114/114 [==============================] - 43s 375ms/step - loss: 0.6131 - accuracy: 0.8082 - val_loss: 0.6358 - val_accuracy: 0.8497
# Epoch 4/50
# 114/114 [==============================] - 43s 374ms/step - loss: 0.5160 - accuracy: 0.8313 - val_loss: 0.5376 - val_accuracy: 0.8497
# Epoch 5/50
# 114/114 [==============================] - 43s 373ms/step - loss: 0.4979 - accuracy: 0.8375 - val_loss: 0.4958 - val_accuracy: 0.8497
# Epoch 6/50
# 114/114 [==============================] - 43s 374ms/step - loss: 0.4808 - accuracy: 0.8414 - val_loss: 0.4398 - val_accuracy: 0.8497
# Epoch 7/50
# 114/114 [==============================] - 42s 372ms/step - loss: 0.4457 - accuracy: 0.8421 - val_loss: 0.4329 - val_accuracy: 0.8497
# Epoch 8/50
# 114/114 [==============================] - 44s 390ms/step - loss: 0.4192 - accuracy: 0.8442 - val_loss: 0.3874 - val_accuracy: 0.8509
# Epoch 9/50
# 114/114 [==============================] - 42s 372ms/step - loss: 0.3743 - accuracy: 0.8527 - val_loss: 0.2974 - val_accuracy: 0.8803
# Epoch 10/50
# 114/114 [==============================] - 43s 375ms/step - loss: 0.3493 - accuracy: 0.8613 - val_loss: 0.2608 - val_accuracy: 0.8871
# Epoch 11/50
# 114/114 [==============================] - 42s 369ms/step - loss: 0.3279 - accuracy: 0.8812 - val_loss: 0.2429 - val_accuracy: 0.9112
# Epoch 12/50
# 114/114 [==============================] - 48s 419ms/step - loss: 0.2920 - accuracy: 0.9021 - val_loss: 0.2403 - val_accuracy: 0.9191
# Epoch 13/50
# 114/114 [==============================] - 42s 373ms/step - loss: 0.2719 - accuracy: 0.9098 - val_loss: 0.2871 - val_accuracy: 0.9147
# Epoch 14/50
# 114/114 [==============================] - 44s 390ms/step - loss: 0.2655 - accuracy: 0.9114 - val_loss: 0.2758 - val_accuracy: 0.9162
# Epoch 15/50
# 114/114 [==============================] - 43s 379ms/step - loss: 0.2695 - accuracy: 0.9148 - val_loss: 0.2582 - val_accuracy: 0.9224
# Epoch 16/50
# 114/114 [==============================] - 43s 379ms/step - loss: 0.2571 - accuracy: 0.9181 - val_loss: 0.2660 - val_accuracy: 0.9232
# Epoch 17/50
# 114/114 [==============================] - 42s 372ms/step - loss: 0.2564 - accuracy: 0.9192 - val_loss: 0.2774 - val_accuracy: 0.9206
# Epoch 18/50
# 114/114 [==============================] - 42s 372ms/step - loss: 0.2420 - accuracy: 0.9259 - val_loss: 0.2636 - val_accuracy: 0.9271
# Epoch 19/50
# 114/114 [==============================] - 43s 373ms/step - loss: 0.2276 - accuracy: 0.9268 - val_loss: 0.2975 - val_accuracy: 0.9268
# Epoch 20/50
# 114/114 [==============================] - 42s 371ms/step - loss: 0.2344 - accuracy: 0.9252 - val_loss: 0.2496 - val_accuracy: 0.9268
# Epoch 21/50
# 114/114 [==============================] - 44s 391ms/step - loss: 0.2309 - accuracy: 0.9277 - val_loss: 0.3121 - val_accuracy: 0.9247
# Epoch 22/50
# 114/114 [==============================] - 42s 368ms/step - loss: 0.2217 - accuracy: 0.9259 - val_loss: 0.3050 - val_accuracy: 0.9244
# Epoch 23/50
# 114/114 [==============================] - 42s 372ms/step - loss: 0.2287 - accuracy: 0.9275 - val_loss: 0.3198 - val_accuracy: 0.9238
# Epoch 24/50
# 114/114 [==============================] - 42s 370ms/step - loss: 0.2203 - accuracy: 0.9296 - val_loss: 0.2815 - val_accuracy: 0.9276
# Epoch 25/50
# 114/114 [==============================] - 43s 374ms/step - loss: 0.2198 - accuracy: 0.9284 - val_loss: 0.4056 - val_accuracy: 0.9091
# Epoch 26/50
# 114/114 [==============================] - 42s 373ms/step - loss: 0.2174 - accuracy: 0.9299 - val_loss: 0.3685 - val_accuracy: 0.9129
# Epoch 27/50
# 114/114 [==============================] - 42s 372ms/step - loss: 0.2180 - accuracy: 0.9277 - val_loss: 0.4126 - val_accuracy: 0.8944
# Epoch 28/50
# 114/114 [==============================] - 44s 388ms/step - loss: 0.2224 - accuracy: 0.9301 - val_loss: 0.3106 - val_accuracy: 0.9297
# Epoch 29/50
# 114/114 [==============================] - 42s 371ms/step - loss: 0.2096 - accuracy: 0.9324 - val_loss: 0.3276 - val_accuracy: 0.9229
# Epoch 30/50
# 114/114 [==============================] - 43s 375ms/step - loss: 0.2173 - accuracy: 0.9280 - val_loss: 0.3230 - val_accuracy: 0.9265
# Epoch 31/50
# 114/114 [==============================] - 42s 371ms/step - loss: 0.2087 - accuracy: 0.9329 - val_loss: 0.3934 - val_accuracy: 0.9021
# Epoch 32/50
# 114/114 [==============================] - 42s 373ms/step - loss: 0.2198 - accuracy: 0.9310 - val_loss: 0.3643 - val_accuracy: 0.9109
# Epoch 33/50
# 114/114 [==============================] - 42s 371ms/step - loss: 0.2111 - accuracy: 0.9296 - val_loss: 0.3494 - val_accuracy: 0.9147
# Epoch 34/50
# 114/114 [==============================] - 43s 376ms/step - loss: 0.2048 - accuracy: 0.9324 - val_loss: 0.3420 - val_accuracy: 0.9171
# Epoch 35/50
# 114/114 [==============================] - 44s 387ms/step - loss: 0.2017 - accuracy: 0.9349 - val_loss: 0.3269 - val_accuracy: 0.9156
# Epoch 36/50
# 114/114 [==============================] - 42s 371ms/step - loss: 0.2033 - accuracy: 0.9301 - val_loss: 0.3789 - val_accuracy: 0.9076
# Epoch 37/50
# 114/114 [==============================] - 43s 373ms/step - loss: 0.1965 - accuracy: 0.9326 - val_loss: 0.3796 - val_accuracy: 0.9047
# Epoch 38/50
# 114/114 [==============================] - 42s 372ms/step - loss: 0.2009 - accuracy: 0.9328 - val_loss: 0.4200 - val_accuracy: 0.8926
# Epoch 39/50
# 114/114 [==============================] - 42s 372ms/step - loss: 0.1987 - accuracy: 0.9322 - val_loss: 0.3501 - val_accuracy: 0.9097
# Epoch 40/50
# 114/114 [==============================] - 42s 372ms/step - loss: 0.2027 - accuracy: 0.9317 - val_loss: 0.3764 - val_accuracy: 0.9121
# Epoch 41/50
# 114/114 [==============================] - 43s 374ms/step - loss: 0.1947 - accuracy: 0.9344 - val_loss: 0.4520 - val_accuracy: 0.8821
# Epoch 42/50
# 114/114 [==============================] - 44s 390ms/step - loss: 0.1890 - accuracy: 0.9337 - val_loss: 0.3257 - val_accuracy: 0.9171
# Epoch 43/50
# 114/114 [==============================] - 43s 374ms/step - loss: 0.1913 - accuracy: 0.9384 - val_loss: 0.4036 - val_accuracy: 0.8900
# Epoch 44/50
# 114/114 [==============================] - 42s 369ms/step - loss: 0.1953 - accuracy: 0.9351 - val_loss: 0.3838 - val_accuracy: 0.9150
# Epoch 45/50
# 114/114 [==============================] - 44s 384ms/step - loss: 0.1943 - accuracy: 0.9354 - val_loss: 0.3294 - val_accuracy: 0.9212
# Epoch 46/50
# 114/114 [==============================] - 42s 369ms/step - loss: 0.1932 - accuracy: 0.9359 - val_loss: 0.2815 - val_accuracy: 0.9297
# Epoch 47/50
# 114/114 [==============================] - 42s 371ms/step - loss: 0.1935 - accuracy: 0.9363 - val_loss: 0.4346 - val_accuracy: 0.8826
# Epoch 48/50
# 114/114 [==============================] - 42s 368ms/step - loss: 0.1942 - accuracy: 0.9326 - val_loss: 0.2662 - val_accuracy: 0.9324
# Epoch 49/50
# 114/114 [==============================] - 44s 389ms/step - loss: 0.1868 - accuracy: 0.9338 - val_loss: 0.4116 - val_accuracy: 0.8868
# Epoch 50/50
# 114/114 [==============================] - 42s 368ms/step - loss: 0.1868 - accuracy: 0.9345 - val_loss: 0.3402 - val_accuracy: 0.9188

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
result = model.evaluate(X_test, y_test, batch_size = 50)
print('Test Loss, Test Accuracy :', result)
# Out:
# 68/68 [==============================] - 5s 81ms/step - loss: 0.3402 - accuracy: 0.9188
# Test Loss, Test Accuracy : [0.34024778008461, 0.9188235402107239]

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
P = model.predict(X_predict)

true = 0
for i in range(X_predict.shape[0]):
    if(np.argmax(P[i]) == np.argmax(y_true[i])):
        true = true + 1

pre_accuracy = 100 * float(true/X_predict.shape[0])        
print('Predict Accuracy: {}' .format(pre_accuracy))
# Out:
# Predict Accuracy: 91.7953242170269

# %%
import seaborn as sns
false = len(X_predict) - true

predict = [true, false]
label = ['true_predict', 'false_predict']

plt.bar(label[0], predict[0])
plt.bar(label[1], predict[1])
plt.title('Predict Accuracy')
plt.xlabel('predict')
plt.ylabel('count')
plt.legend(['true_predict', 'false_predict'], loc='upper left')
plt.show()
