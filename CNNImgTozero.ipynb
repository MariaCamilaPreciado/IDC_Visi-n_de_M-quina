# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import glob
import random
import warnings
warnings.filterwarnings(action = 'ignore')
import matplotlib.pyplot as plt

from PIL import Image

random.seed(98)
np.random.seed(98)

# %%
breast_img = glob.glob('/content/drive/MyDrive/Visión de Máquina /Entrega/BancoImagenes/tozero/**/*.png', recursive = True)

# %%
for imgname in breast_img[:5]:
    print(imgname)
# Out:
# /content/drive/MyDrive/Visión de Máquina /Entrega/BancoImagenes/tozero/0/6421_class0.png
# /content/drive/MyDrive/Visión de Máquina /Entrega/BancoImagenes/tozero/0/6422_class0.png
# /content/drive/MyDrive/Visión de Máquina /Entrega/BancoImagenes/tozero/0/6423_class0.png
# /content/drive/MyDrive/Visión de Máquina /Entrega/BancoImagenes/tozero/0/6424_class0.png
# /content/drive/MyDrive/Visión de Máquina /Entrega/BancoImagenes/tozero/0/6425_class0.png

# %%
non_img = []
can_img = []

for img in breast_img:
    if img[-5] == '0' :
        non_img.append(img)
    
    elif img[-5] == '1' :
        can_img.append(img)

# %%
non_num = len(non_img)
can_num = len(can_img)
        
total_img_num = non_num + can_num
        
print('Number of Images in IDC (-): {}' .format(non_num))
print('Number of Images in IDC (+) : {}' .format(can_num))
print('Total Number of Images : {}' .format(total_img_num))
# Out:
# Number of Images in IDC (-): 7421
# Number of Images in IDC (+) : 5667
# Total Number of Images : 13088

# %%
from keras.preprocessing import image

plt.figure(figsize = (15, 15))

some_non = np.random.randint(0, len(non_img), 18)
some_can = np.random.randint(0, len(can_img), 18)

s = 0
for num in some_non:
    
        img = image.load_img((non_img[num]), target_size=(100, 100))
        img = image.img_to_array(img)
        
        plt.subplot(6, 6, 2*s+1)
        plt.axis('off')
        plt.title('IDC (-)')
        plt.imshow(img.astype('uint8'))
        s += 1
        
s = 1
for num in some_can:
    
        img = image.load_img((can_img[num]), target_size=(100, 100))
        img = image.img_to_array(img)
        
        plt.subplot(6, 6, 2*s)
        plt.axis('off')        
        plt.title('IDC (+)')
        plt.imshow(img.astype('uint8'))
        s += 1

# %%
from matplotlib.image import imread
import cv2

some_non_img = random.sample(non_img, len(can_img))
some_can_img = random.sample(can_img, len(can_img))

non_img_arr = []
can_img_arr = []

for img in some_non_img:
        
    n_img = cv2.imread(img, cv2.IMREAD_COLOR)
    n_img_size = cv2.resize(n_img, (50, 50), interpolation = cv2.INTER_LINEAR)
    non_img_arr.append([n_img_size, 0])
    
for img in some_can_img:
    
    c_img = cv2.imread(img, cv2.IMREAD_COLOR)
    c_img_size = cv2.resize(c_img, (50, 50), interpolation = cv2.INTER_LINEAR)
    can_img_arr.append([c_img_size, 1])

# %%
X = []
y = []

breast_img_arr = np.concatenate((non_img_arr, can_img_arr))
random.shuffle(breast_img_arr)

for feature, label in breast_img_arr:
    X.append(feature)
    y.append(label)
    
X = np.array(X)
y = np.array(y)

print('X shape : {}' .format(X.shape))
# Out:
# X shape : (11334, 50, 50, 3)

# %%
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical

X_train, X_predict, y_train, y_true = train_test_split(X, y, test_size = 0.2, random_state = 7)

rate = 0.5
num = int(X.shape[0] * rate)

X_test = X_train[num:]
X_train = X_train[:num]

y_test = y_train[num:]
y_train = y_train[:num]

y_train = to_categorical(y_train, 2)
y_test = to_categorical(y_test, 2)
y_true = to_categorical(y_true, 2)

print('X_train shape : {}' .format(X_train.shape))
print('X_test shape : {}' .format(X_test.shape))
print('X_predict shape : {}' .format(X_predict.shape))
print('y_train shape : {}' .format(y_train.shape))
print('y_test shape : {}' .format(y_test.shape))
print('y_true shape : {}' .format(y_true.shape))
# Out:
# X_train shape : (5667, 50, 50, 3)
# X_test shape : (3400, 50, 50, 3)
# X_predict shape : (2267, 50, 50, 3)
# y_train shape : (5667, 2)
# y_test shape : (3400, 2)
# y_true shape : (2267, 2)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense

model = Sequential()

model.add(Conv2D(32, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 3)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 3)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 3)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 3)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation = 'relu'))

model.add(Dropout(0.5))
model.add(Dense(2, activation = 'sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 50, 50, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 25, 25, 32)       0
#  )
#
#  dropout (Dropout)           (None, 25, 25, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 25, 25, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 128)         0
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 128)         147584
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 3, 3, 128)         0
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 128)               147584
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 388,674
# Trainable params: 388,674
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

Adam = Adam(learning_rate = 0.0001)
model.compile(loss = 'binary_crossentropy', optimizer = Adam, metrics = ['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = 50, batch_size = 50)
# Out:
# Epoch 1/50
# 114/114 [==============================] - 57s 486ms/step - loss: 4.1138 - accuracy: 0.8278 - val_loss: 0.2331 - val_accuracy: 0.9159
# Epoch 2/50
# 114/114 [==============================] - 47s 412ms/step - loss: 0.6574 - accuracy: 0.8712 - val_loss: 0.2302 - val_accuracy: 0.9103
# Epoch 3/50
# 114/114 [==============================] - 48s 422ms/step - loss: 0.4473 - accuracy: 0.8719 - val_loss: 0.2447 - val_accuracy: 0.9082
# Epoch 4/50
# 114/114 [==============================] - 47s 409ms/step - loss: 0.3809 - accuracy: 0.8814 - val_loss: 0.2398 - val_accuracy: 0.9079
# Epoch 5/50
# 114/114 [==============================] - 47s 410ms/step - loss: 0.3174 - accuracy: 0.8913 - val_loss: 0.2566 - val_accuracy: 0.9115
# Epoch 6/50
# 114/114 [==============================] - 46s 403ms/step - loss: 0.3214 - accuracy: 0.8839 - val_loss: 0.2381 - val_accuracy: 0.9106
# Epoch 7/50
# 114/114 [==============================] - 48s 420ms/step - loss: 0.3157 - accuracy: 0.8885 - val_loss: 0.2508 - val_accuracy: 0.9115
# Epoch 8/50
# 114/114 [==============================] - 46s 404ms/step - loss: 0.2939 - accuracy: 0.8945 - val_loss: 0.2779 - val_accuracy: 0.9082
# Epoch 9/50
# 114/114 [==============================] - 46s 407ms/step - loss: 0.2996 - accuracy: 0.8902 - val_loss: 0.2518 - val_accuracy: 0.9085
# Epoch 10/50
# 114/114 [==============================] - 46s 407ms/step - loss: 0.3069 - accuracy: 0.8890 - val_loss: 0.2786 - val_accuracy: 0.9103
# Epoch 11/50
# 114/114 [==============================] - 50s 436ms/step - loss: 0.2854 - accuracy: 0.8918 - val_loss: 0.2419 - val_accuracy: 0.9132
# Epoch 12/50
# 114/114 [==============================] - 47s 412ms/step - loss: 0.2938 - accuracy: 0.8996 - val_loss: 0.2751 - val_accuracy: 0.9115
# Epoch 13/50
# 114/114 [==============================] - 46s 407ms/step - loss: 0.2815 - accuracy: 0.8924 - val_loss: 0.2605 - val_accuracy: 0.9100
# Epoch 14/50
# 114/114 [==============================] - 48s 421ms/step - loss: 0.2877 - accuracy: 0.8927 - val_loss: 0.2432 - val_accuracy: 0.9141
# Epoch 15/50
# 114/114 [==============================] - 46s 406ms/step - loss: 0.2747 - accuracy: 0.8957 - val_loss: 0.2414 - val_accuracy: 0.9121
# Epoch 16/50
# 114/114 [==============================] - 46s 404ms/step - loss: 0.2757 - accuracy: 0.8966 - val_loss: 0.2679 - val_accuracy: 0.9132
# Epoch 17/50
# 114/114 [==============================] - 46s 403ms/step - loss: 0.2673 - accuracy: 0.8977 - val_loss: 0.2645 - val_accuracy: 0.9129
# Epoch 18/50
# 114/114 [==============================] - 48s 418ms/step - loss: 0.2686 - accuracy: 0.9007 - val_loss: 0.2635 - val_accuracy: 0.9153
# Epoch 19/50
# 114/114 [==============================] - 46s 406ms/step - loss: 0.2650 - accuracy: 0.8996 - val_loss: 0.2874 - val_accuracy: 0.9132
# Epoch 20/50
# 114/114 [==============================] - 46s 403ms/step - loss: 0.2650 - accuracy: 0.8973 - val_loss: 0.2737 - val_accuracy: 0.9103
# Epoch 21/50
# 114/114 [==============================] - 46s 403ms/step - loss: 0.2716 - accuracy: 0.8989 - val_loss: 0.2702 - val_accuracy: 0.9138
# Epoch 22/50
# 114/114 [==============================] - 48s 424ms/step - loss: 0.2571 - accuracy: 0.8984 - val_loss: 0.2472 - val_accuracy: 0.9156
# Epoch 23/50
# 114/114 [==============================] - 46s 402ms/step - loss: 0.2556 - accuracy: 0.8985 - val_loss: 0.2467 - val_accuracy: 0.9147
# Epoch 24/50
# 114/114 [==============================] - 46s 403ms/step - loss: 0.2551 - accuracy: 0.9007 - val_loss: 0.2526 - val_accuracy: 0.9165
# Epoch 25/50
# 114/114 [==============================] - 46s 402ms/step - loss: 0.2591 - accuracy: 0.9005 - val_loss: 0.3102 - val_accuracy: 0.9124
# Epoch 26/50
# 114/114 [==============================] - 48s 418ms/step - loss: 0.2542 - accuracy: 0.9001 - val_loss: 0.2956 - val_accuracy: 0.9132
# Epoch 27/50
# 114/114 [==============================] - 46s 401ms/step - loss: 0.2506 - accuracy: 0.9008 - val_loss: 0.2951 - val_accuracy: 0.9085
# Epoch 28/50
# 114/114 [==============================] - 46s 405ms/step - loss: 0.2495 - accuracy: 0.9007 - val_loss: 0.2679 - val_accuracy: 0.9076
# Epoch 29/50
# 114/114 [==============================] - 47s 408ms/step - loss: 0.2521 - accuracy: 0.9015 - val_loss: 0.3109 - val_accuracy: 0.9168
# Epoch 30/50
# 114/114 [==============================] - 47s 412ms/step - loss: 0.2465 - accuracy: 0.9024 - val_loss: 0.3081 - val_accuracy: 0.9156
# Epoch 31/50
# 114/114 [==============================] - 46s 402ms/step - loss: 0.2495 - accuracy: 0.9028 - val_loss: 0.2921 - val_accuracy: 0.9162
# Epoch 32/50
# 114/114 [==============================] - 46s 404ms/step - loss: 0.2506 - accuracy: 0.9001 - val_loss: 0.2747 - val_accuracy: 0.9156
# Epoch 33/50
# 114/114 [==============================] - 48s 424ms/step - loss: 0.2525 - accuracy: 0.8989 - val_loss: 0.3349 - val_accuracy: 0.9171
# Epoch 34/50
# 114/114 [==============================] - 46s 402ms/step - loss: 0.2438 - accuracy: 0.9044 - val_loss: 0.2820 - val_accuracy: 0.9153
# Epoch 35/50
# 114/114 [==============================] - 46s 404ms/step - loss: 0.2458 - accuracy: 0.9047 - val_loss: 0.2757 - val_accuracy: 0.9138
# Epoch 36/50
# 114/114 [==============================] - 47s 408ms/step - loss: 0.2433 - accuracy: 0.9029 - val_loss: 0.2812 - val_accuracy: 0.9159
# Epoch 37/50
# 114/114 [==============================] - 48s 423ms/step - loss: 0.2400 - accuracy: 0.9038 - val_loss: 0.3267 - val_accuracy: 0.9138
# Epoch 38/50
# 114/114 [==============================] - 46s 405ms/step - loss: 0.2447 - accuracy: 0.9024 - val_loss: 0.2770 - val_accuracy: 0.9150
# Epoch 39/50
# 114/114 [==============================] - 46s 402ms/step - loss: 0.2420 - accuracy: 0.9065 - val_loss: 0.3124 - val_accuracy: 0.9159
# Epoch 40/50
# 114/114 [==============================] - 48s 422ms/step - loss: 0.2372 - accuracy: 0.9026 - val_loss: 0.2844 - val_accuracy: 0.9150
# Epoch 41/50
# 114/114 [==============================] - 47s 410ms/step - loss: 0.2398 - accuracy: 0.9074 - val_loss: 0.2887 - val_accuracy: 0.9135
# Epoch 42/50
# 114/114 [==============================] - 46s 407ms/step - loss: 0.2399 - accuracy: 0.9051 - val_loss: 0.2616 - val_accuracy: 0.9112
# Epoch 43/50
# 114/114 [==============================] - 46s 405ms/step - loss: 0.2388 - accuracy: 0.9028 - val_loss: 0.2794 - val_accuracy: 0.9179
# Epoch 44/50
# 114/114 [==============================] - 48s 419ms/step - loss: 0.2359 - accuracy: 0.9081 - val_loss: 0.2704 - val_accuracy: 0.9159
# Epoch 45/50
# 114/114 [==============================] - 46s 402ms/step - loss: 0.2336 - accuracy: 0.9051 - val_loss: 0.2854 - val_accuracy: 0.9174
# Epoch 46/50
# 114/114 [==============================] - 46s 401ms/step - loss: 0.2344 - accuracy: 0.9049 - val_loss: 0.2585 - val_accuracy: 0.9179
# Epoch 47/50
# 114/114 [==============================] - 46s 404ms/step - loss: 0.2404 - accuracy: 0.9051 - val_loss: 0.2885 - val_accuracy: 0.9153
# Epoch 48/50
# 114/114 [==============================] - 48s 418ms/step - loss: 0.2326 - accuracy: 0.9047 - val_loss: 0.2956 - val_accuracy: 0.9165
# Epoch 49/50
# 114/114 [==============================] - 46s 404ms/step - loss: 0.2391 - accuracy: 0.9051 - val_loss: 0.2725 - val_accuracy: 0.9165
# Epoch 50/50
# 114/114 [==============================] - 46s 406ms/step - loss: 0.2305 - accuracy: 0.9070 - val_loss: 0.2704 - val_accuracy: 0.9144

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
result = model.evaluate(X_test, y_test, batch_size = 50)
print('Test Loss, Test Accuracy :', result)
# Out:
# 68/68 [==============================] - 10s 150ms/step - loss: 0.2704 - accuracy: 0.9144
# Test Loss, Test Accuracy : [0.27035287022590637, 0.9144117832183838]

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
P = model.predict(X_predict)

true = 0
for i in range(X_predict.shape[0]):
    if(np.argmax(P[i]) == np.argmax(y_true[i])):
        true = true + 1

pre_accuracy = 100 * float(true/X_predict.shape[0])        
print('Predict Accuracy: {}' .format(pre_accuracy))
# Out:
# Predict Accuracy: 90.29554477282753

# %%
import seaborn as sns
false = len(X_predict) - true

predict = [true, false]
label = ['true_predict', 'false_predict']

plt.bar(label[0], predict[0])
plt.bar(label[1], predict[1])
plt.title('Predict Accuracy')
plt.xlabel('predict')
plt.ylabel('count')
plt.legend(['true_predict', 'false_predict'], loc='upper left')
plt.show()
