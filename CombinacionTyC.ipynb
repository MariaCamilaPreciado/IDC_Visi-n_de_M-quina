# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import pandas as pd
import multiprocessing as mp
import os
import cv2
from PIL import Image, ImageFilter
from scipy.ndimage import gaussian_filter
from scipy import ndimage
from scipy import misc
from PIL import Image
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib import colors
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
dir = ""
FileListColor = os.listdir('/content/drive/MyDrive/VisiondeMaquina/Entrega/BancoImagenes/Color/1/')

# %%
dir = ""
FileListTozero = os.listdir('/content/drive/MyDrive/VisiondeMaquina/Entrega/BancoImagenes/tozero/1/')

# %%
ListImg=[]
Dir= "/content/drive/MyDrive/VisiondeMaquina/Entrega/BancoImagenes/tozero/1/"
for nameImg in FileListTozero:
    Img = cv2.imread(Dir+nameImg,0)
    ListImg.append(Img)

# %%
plt.imshow(ListImg[0],cmap = 'gray')

# %%
ListImgColor=[]
Dir= "/content/drive/MyDrive/VisiondeMaquina/Entrega/BancoImagenes/Color/1/"
for nameImg in FileListColor:
    Img = cv2.imread(Dir+nameImg,0)
    ListImgColor.append(Img)

# %%
NImg=len(ListImg)
NImg
# Out:
# 5667

# %%
NImg=len(ListImgColor)
NImg
# Out:
# 5667

# %%
BG01=[]
for n in range (5667): 
  dst = cv2.addWeighted(ListImg[n], 0.5, ListImgColor[n], 0.7, 0)
  BG01.append(dst)

# %%
DirNewCombination = '/content/drive/MyDrive/VisiondeMaquina/Entrega/BancoImagenes/CombinacionTozeroColor/1/'

# %%
for a in range(len(BG01)):
   cv2.imwrite(DirNewCombination+ str(a)+'_class1' + '.png', BG01[a])
