# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import glob
import random
import warnings
warnings.filterwarnings(action = 'ignore')
import matplotlib.pyplot as plt
import cv2
from PIL import Image

random.seed(98)
np.random.seed(98)

# %%
breast_img = glob.glob('drive/MyDrive/Colab Notebooks/ClasesDoctorado/VisionDeMaquina/bordes/Sobel/*/**.png', recursive = True)

# %%
for imgname in breast_img[:]:
    print(imgname)

# %%
len(breast_img)
# Out:
# 13088

# %%
non_img = []
can_img = []

for img in breast_img:
    if img[-5] == '0' :
        non_img.append(img)
    
    elif img[-5] == '1' :
        can_img.append(img)

# %%
non_num = len(non_img)
can_num = len(can_img)
        
total_img_num = non_num + can_num
        
print('Number of Images in IDC (-): {}' .format(non_num))
print('Number of Images in IDC (+) : {}' .format(can_num))
print('Total Number of Images : {}' .format(total_img_num))
# Out:
# Number of Images in IDC (-): 7421
# Number of Images in IDC (+) : 5667
# Total Number of Images : 13088

# %%
from keras.preprocessing import image

plt.figure(figsize = (15, 15))

some_non = np.random.randint(0, len(non_img), 18)
some_can = np.random.randint(0, len(can_img), 18)

s = 0
for num in some_non:
    
        img = image.load_img((non_img[num]), target_size=(100, 100))
        img = image.img_to_array(img)
        
        plt.subplot(6, 6, 2*s+1)
        plt.axis('off')
        plt.title('IDC (-)')
        plt.imshow(img.astype('uint8'))
        s += 1
        
s = 1
for num in some_can:
    
        img = image.load_img((can_img[num]), target_size=(100, 100))
        img = image.img_to_array(img)
        
        plt.subplot(6, 6, 2*s)
        plt.axis('off')        
        plt.title('IDC (+)')
        plt.imshow(img.astype('uint8'))
        s += 1

# %%
from matplotlib.image import imread
import cv2

some_non_img = random.sample(non_img, len(can_img))
some_can_img = random.sample(can_img, len(can_img))

non_img_arr = []
can_img_arr = []

for img in some_non_img:
        
    n_img = cv2.imread(img, 0)
    n_img_size = cv2.resize(n_img, (50, 50), interpolation = cv2.INTER_LINEAR)
    non_img_arr.append([n_img_size, 0])
    
for img in some_can_img:
    
    c_img = cv2.imread(img, 0)
    c_img_size = cv2.resize(c_img, (50, 50), interpolation = cv2.INTER_LINEAR)
    can_img_arr.append([c_img_size, 1])

# %%
X = []
y = []

breast_img_arr = np.concatenate((non_img_arr, can_img_arr))
random.shuffle(breast_img_arr)

for feature, label in breast_img_arr:
    X.append(feature)
    y.append(label)
    
X = np.array(X)
y = np.array(y)

print('X shape : {}' .format(X.shape))
# Out:
# X shape : (11334, 50, 50)

# %%
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical

X_train, X_predict, y_train, y_true = train_test_split(X, y, test_size = 0.2, random_state = 7)

rate = 0.5
num = int(X.shape[0] * rate)

X_test = X_train[num:]
X_train = X_train[:num]

y_test = y_train[num:]
y_train = y_train[:num]

y_train = to_categorical(y_train, 2)
y_test = to_categorical(y_test, 2)
y_true = to_categorical(y_true, 2)

print('X_train shape : {}' .format(X_train.shape))
print('X_test shape : {}' .format(X_test.shape))
print('X_predict shape : {}' .format(X_predict.shape))
print('y_train shape : {}' .format(y_train.shape))
print('y_test shape : {}' .format(y_test.shape))
print('y_true shape : {}' .format(y_true.shape))
# Out:
# X_train shape : (5667, 50, 50)
# X_test shape : (3400, 50, 50)
# X_predict shape : (2267, 50, 50)
# y_train shape : (5667, 2)
# y_test shape : (3400, 2)
# y_true shape : (2267, 2)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense

model = Sequential()

model.add(Conv2D(32, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 1)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 1)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 1)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 1)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation = 'relu'))

model.add(Dropout(0.5))
model.add(Dense(2, activation = 'sigmoid'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 50, 50, 32)        320
#
#  max_pooling2d_4 (MaxPooling  (None, 25, 25, 32)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 25, 25, 32)        0
#
#  conv2d_5 (Conv2D)           (None, 25, 25, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 12, 12, 64)        0
#
#  conv2d_6 (Conv2D)           (None, 12, 12, 128)       73856
#
#  max_pooling2d_6 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  dropout_7 (Dropout)         (None, 6, 6, 128)         0
#
#  conv2d_7 (Conv2D)           (None, 6, 6, 128)         147584
#
#  max_pooling2d_7 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  dropout_8 (Dropout)         (None, 3, 3, 128)         0
#
#  flatten_1 (Flatten)         (None, 1152)              0
#
#  dense_2 (Dense)             (None, 128)               147584
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 388,098
# Trainable params: 388,098
# Non-trainable params: 0
# _________________________________________________________________

# %%
# !pip install Adam
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Adam in /usr/local/lib/python3.7/dist-packages (0.0.0.dev0)

# %%
from tensorflow.keras.optimizers import Adam

Adam = Adam(learning_rate = 0.0001)
model.compile(loss = 'binary_crossentropy', optimizer = Adam, metrics = ['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = 35, batch_size = 50)
# Out:
# Epoch 1/35
# 114/114 [==============================] - 58s 499ms/step - loss: 2.3263 - accuracy: 0.7890 - val_loss: 0.6182 - val_accuracy: 0.8285
# Epoch 2/35
# 114/114 [==============================] - 44s 390ms/step - loss: 0.6261 - accuracy: 0.8071 - val_loss: 0.6401 - val_accuracy: 0.8432
# Epoch 3/35
# 114/114 [==============================] - 48s 417ms/step - loss: 0.5411 - accuracy: 0.8310 - val_loss: 0.6378 - val_accuracy: 0.8432
# Epoch 4/35
# 114/114 [==============================] - 44s 387ms/step - loss: 0.5136 - accuracy: 0.8419 - val_loss: 0.6233 - val_accuracy: 0.8432
# Epoch 5/35
# 114/114 [==============================] - 44s 390ms/step - loss: 0.5020 - accuracy: 0.8449 - val_loss: 0.6219 - val_accuracy: 0.8432
# Epoch 6/35
# 114/114 [==============================] - 44s 389ms/step - loss: 0.4841 - accuracy: 0.8447 - val_loss: 0.6115 - val_accuracy: 0.8432
# Epoch 7/35
# 114/114 [==============================] - 44s 387ms/step - loss: 0.4877 - accuracy: 0.8474 - val_loss: 0.6100 - val_accuracy: 0.8432
# Epoch 8/35
# 114/114 [==============================] - 45s 392ms/step - loss: 0.4651 - accuracy: 0.8481 - val_loss: 0.6205 - val_accuracy: 0.8432
# Epoch 9/35
# 114/114 [==============================] - 45s 394ms/step - loss: 0.4613 - accuracy: 0.8495 - val_loss: 0.6236 - val_accuracy: 0.8432
# Epoch 10/35
# 114/114 [==============================] - 46s 405ms/step - loss: 0.4496 - accuracy: 0.8490 - val_loss: 0.6332 - val_accuracy: 0.8432
# Epoch 11/35
# 114/114 [==============================] - 44s 387ms/step - loss: 0.4399 - accuracy: 0.8490 - val_loss: 0.6222 - val_accuracy: 0.8432
# Epoch 12/35
# 114/114 [==============================] - 44s 385ms/step - loss: 0.4356 - accuracy: 0.8493 - val_loss: 0.6084 - val_accuracy: 0.8432
# Epoch 13/35
# 114/114 [==============================] - 44s 389ms/step - loss: 0.4216 - accuracy: 0.8488 - val_loss: 0.6204 - val_accuracy: 0.8432
# Epoch 14/35
# 114/114 [==============================] - 44s 388ms/step - loss: 0.4156 - accuracy: 0.8497 - val_loss: 0.6189 - val_accuracy: 0.8432
# Epoch 15/35
# 114/114 [==============================] - 46s 403ms/step - loss: 0.4061 - accuracy: 0.8491 - val_loss: 0.6009 - val_accuracy: 0.8432
# Epoch 16/35
# 114/114 [==============================] - 44s 387ms/step - loss: 0.3884 - accuracy: 0.8490 - val_loss: 0.5718 - val_accuracy: 0.8429
# Epoch 17/35
# 114/114 [==============================] - 44s 387ms/step - loss: 0.3725 - accuracy: 0.8486 - val_loss: 0.5480 - val_accuracy: 0.8432
# Epoch 18/35
# 114/114 [==============================] - 44s 388ms/step - loss: 0.3626 - accuracy: 0.8491 - val_loss: 0.5397 - val_accuracy: 0.8432
# Epoch 19/35
# 114/114 [==============================] - 44s 390ms/step - loss: 0.3525 - accuracy: 0.8497 - val_loss: 0.4267 - val_accuracy: 0.8432
# Epoch 20/35
# 114/114 [==============================] - 44s 389ms/step - loss: 0.3497 - accuracy: 0.8490 - val_loss: 0.5038 - val_accuracy: 0.8432
# Epoch 21/35
# 114/114 [==============================] - 44s 388ms/step - loss: 0.3406 - accuracy: 0.8498 - val_loss: 0.4059 - val_accuracy: 0.8432
# Epoch 22/35
# 114/114 [==============================] - 44s 385ms/step - loss: 0.3296 - accuracy: 0.8497 - val_loss: 0.4441 - val_accuracy: 0.8432
# Epoch 23/35
# 114/114 [==============================] - 46s 402ms/step - loss: 0.3208 - accuracy: 0.8497 - val_loss: 0.5247 - val_accuracy: 0.8432
# Epoch 24/35
# 114/114 [==============================] - 44s 386ms/step - loss: 0.3300 - accuracy: 0.8493 - val_loss: 0.4623 - val_accuracy: 0.8432
# Epoch 25/35
# 114/114 [==============================] - 44s 385ms/step - loss: 0.3127 - accuracy: 0.8500 - val_loss: 0.4041 - val_accuracy: 0.8432
# Epoch 26/35
# 114/114 [==============================] - 44s 383ms/step - loss: 0.3133 - accuracy: 0.8491 - val_loss: 0.4330 - val_accuracy: 0.8432
# Epoch 27/35
# 114/114 [==============================] - 44s 383ms/step - loss: 0.3119 - accuracy: 0.8502 - val_loss: 0.3131 - val_accuracy: 0.8432
# Epoch 28/35
# 114/114 [==============================] - 44s 384ms/step - loss: 0.3066 - accuracy: 0.8495 - val_loss: 0.3411 - val_accuracy: 0.8432
# Epoch 29/35
# 114/114 [==============================] - 46s 400ms/step - loss: 0.3039 - accuracy: 0.8497 - val_loss: 0.3590 - val_accuracy: 0.8432
# Epoch 30/35
# 114/114 [==============================] - 44s 384ms/step - loss: 0.3047 - accuracy: 0.8500 - val_loss: 0.3204 - val_accuracy: 0.8432
# Epoch 31/35
# 114/114 [==============================] - 44s 384ms/step - loss: 0.3009 - accuracy: 0.8504 - val_loss: 0.3567 - val_accuracy: 0.8432
# Epoch 32/35
# 114/114 [==============================] - 44s 383ms/step - loss: 0.2994 - accuracy: 0.8498 - val_loss: 0.3137 - val_accuracy: 0.8432
# Epoch 33/35
# 114/114 [==============================] - 44s 384ms/step - loss: 0.2937 - accuracy: 0.8505 - val_loss: 0.2852 - val_accuracy: 0.8432
# Epoch 34/35
# 114/114 [==============================] - 44s 386ms/step - loss: 0.2952 - accuracy: 0.8527 - val_loss: 0.3691 - val_accuracy: 0.8432
# Epoch 35/35
# 114/114 [==============================] - 44s 386ms/step - loss: 0.2935 - accuracy: 0.8514 - val_loss: 0.3123 - val_accuracy: 0.8441

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
result = model.evaluate(X_test, y_test, batch_size = 50)
print('Test Loss, Test Accuracy :', result)
# Out:
# 68/68 [==============================] - 5s 79ms/step - loss: 0.3123 - accuracy: 0.8441
# Test Loss, Test Accuracy : [0.31230148673057556, 0.8441176414489746]

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
P = model.predict(X_predict)

true = 0
for i in range(X_predict.shape[0]):
    if(np.argmax(P[i]) == np.argmax(y_true[i])):
        true = true + 1

pre_accuracy = 100 * float(true/X_predict.shape[0])        
print('Predict Accuracy: {}' .format(pre_accuracy))
# Out:
# Predict Accuracy: 85.13453903837672

# %%
import seaborn as sns
false = len(X_predict) - true

predict = [true, false]
label = ['true_predict', 'false_predict']

plt.bar(label[0], predict[0])
plt.bar(label[1], predict[1])
plt.title('Predict Accuracy')
plt.xlabel('predict')
plt.ylabel('count')
plt.legend(['true_predict', 'false_predict'], loc='upper left')
plt.show()
