# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import glob
import random
import warnings
warnings.filterwarnings(action = 'ignore')
import matplotlib.pyplot as plt
import cv2
from PIL import Image

random.seed(98)
np.random.seed(98)

# %%
breast_img = glob.glob('drive/MyDrive/Colab Notebooks/ClasesDoctorado/VisionDeMaquina/bordes/Kirsch/*/**.png', recursive = True)

# %%
for imgname in breast_img[:]:
    print(imgname)

# %%
len(breast_img)
# Out:
# 13088

# %%
non_img = []
can_img = []

for img in breast_img:
    if img[-5] == '0' :
        non_img.append(img)
    
    elif img[-5] == '1' :
        can_img.append(img)

# %%
non_num = len(non_img)
can_num = len(can_img)
        
total_img_num = non_num + can_num
        
print('Number of Images in IDC (-): {}' .format(non_num))
print('Number of Images in IDC (+) : {}' .format(can_num))
print('Total Number of Images : {}' .format(total_img_num))
# Out:
# Number of Images in IDC (-): 7421
# Number of Images in IDC (+) : 5667
# Total Number of Images : 13088

# %%
from keras.preprocessing import image

plt.figure(figsize = (15, 15))

some_non = np.random.randint(0, len(non_img), 18)
some_can = np.random.randint(0, len(can_img), 18)

s = 0
for num in some_non:
    
        img = image.load_img((non_img[num]), target_size=(100, 100))
        img = image.img_to_array(img)
        
        plt.subplot(6, 6, 2*s+1)
        plt.axis('off')
        plt.title('IDC (-)')
        plt.imshow(img.astype('uint8'))
        s += 1
        
s = 1
for num in some_can:
    
        img = image.load_img((can_img[num]), target_size=(100, 100))
        img = image.img_to_array(img)
        
        plt.subplot(6, 6, 2*s)
        plt.axis('off')        
        plt.title('IDC (+)')
        plt.imshow(img.astype('uint8'))
        s += 1

# %%
from matplotlib.image import imread
import cv2

some_non_img = random.sample(non_img, len(can_img))
some_can_img = random.sample(can_img, len(can_img))

non_img_arr = []
can_img_arr = []

for img in some_non_img:
        
    n_img = cv2.imread(img, 0)
    n_img_size = cv2.resize(n_img, (50, 50), interpolation = cv2.INTER_LINEAR)
    non_img_arr.append([n_img_size, 0])
    
for img in some_can_img:
    
    c_img = cv2.imread(img, 0)
    c_img_size = cv2.resize(c_img, (50, 50), interpolation = cv2.INTER_LINEAR)
    can_img_arr.append([c_img_size, 1])

# %%
X = []
y = []

breast_img_arr = np.concatenate((non_img_arr, can_img_arr))
random.shuffle(breast_img_arr)

for feature, label in breast_img_arr:
    X.append(feature)
    y.append(label)
    
X = np.array(X)
y = np.array(y)

print('X shape : {}' .format(X.shape))
# Out:
# X shape : (11334, 50, 50)

# %%
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical

X_train, X_predict, y_train, y_true = train_test_split(X, y, test_size = 0.2, random_state = 7)

rate = 0.5
num = int(X.shape[0] * rate)

X_test = X_train[num:]
X_train = X_train[:num]

y_test = y_train[num:]
y_train = y_train[:num]

y_train = to_categorical(y_train, 2)
y_test = to_categorical(y_test, 2)
y_true = to_categorical(y_true, 2)

print('X_train shape : {}' .format(X_train.shape))
print('X_test shape : {}' .format(X_test.shape))
print('X_predict shape : {}' .format(X_predict.shape))
print('y_train shape : {}' .format(y_train.shape))
print('y_test shape : {}' .format(y_test.shape))
print('y_true shape : {}' .format(y_true.shape))
# Out:
# X_train shape : (5667, 50, 50)
# X_test shape : (3400, 50, 50)
# X_predict shape : (2267, 50, 50)
# y_train shape : (5667, 2)
# y_test shape : (3400, 2)
# y_true shape : (2267, 2)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense

model = Sequential()

model.add(Conv2D(32, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 1)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 1)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 1)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 1)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation = 'relu'))

model.add(Dropout(0.5))
model.add(Dense(2, activation = 'sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 50, 50, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 25, 25, 32)       0
#  )
#
#  dropout (Dropout)           (None, 25, 25, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 25, 25, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 128)         0
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 128)         147584
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 3, 3, 128)         0
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 128)               147584
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 388,098
# Trainable params: 388,098
# Non-trainable params: 0
# _________________________________________________________________

# %%
# !pip install Adam
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Adam
#   Downloading adam-0.0.0.dev0-py2.py3-none-any.whl (2.6 kB)
# Installing collected packages: Adam
# Successfully installed Adam-0.0.0.dev0

# %%
from tensorflow.keras.optimizers import Adam

Adam = Adam(learning_rate = 0.0001)
model.compile(loss = 'binary_crossentropy', optimizer = Adam, metrics = ['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = 50, batch_size = 50)
# Out:
# Epoch 1/50
# 114/114 [==============================] - 52s 431ms/step - loss: 3.1699 - accuracy: 0.7893 - val_loss: 0.6357 - val_accuracy: 0.8300
# Epoch 2/50
# 114/114 [==============================] - 42s 368ms/step - loss: 0.6854 - accuracy: 0.8126 - val_loss: 0.6307 - val_accuracy: 0.8497
# Epoch 3/50
# 114/114 [==============================] - 43s 381ms/step - loss: 0.5543 - accuracy: 0.8287 - val_loss: 0.6202 - val_accuracy: 0.8497
# Epoch 4/50
# 114/114 [==============================] - 42s 366ms/step - loss: 0.5340 - accuracy: 0.8362 - val_loss: 0.6384 - val_accuracy: 0.8497
# Epoch 5/50
# 114/114 [==============================] - 44s 384ms/step - loss: 0.5125 - accuracy: 0.8422 - val_loss: 0.6093 - val_accuracy: 0.8497
# Epoch 6/50
# 114/114 [==============================] - 42s 368ms/step - loss: 0.4952 - accuracy: 0.8458 - val_loss: 0.5875 - val_accuracy: 0.8497
# Epoch 7/50
# 114/114 [==============================] - 42s 369ms/step - loss: 0.4922 - accuracy: 0.8444 - val_loss: 0.6038 - val_accuracy: 0.8497
# Epoch 8/50
# 114/114 [==============================] - 42s 368ms/step - loss: 0.4934 - accuracy: 0.8474 - val_loss: 0.6078 - val_accuracy: 0.8497
# Epoch 9/50
# 114/114 [==============================] - 42s 370ms/step - loss: 0.4750 - accuracy: 0.8475 - val_loss: 0.5908 - val_accuracy: 0.8497
# Epoch 10/50
# 114/114 [==============================] - 42s 365ms/step - loss: 0.4759 - accuracy: 0.8467 - val_loss: 0.5852 - val_accuracy: 0.8497
# Epoch 11/50
# 114/114 [==============================] - 42s 371ms/step - loss: 0.4808 - accuracy: 0.8474 - val_loss: 0.5811 - val_accuracy: 0.8497
# Epoch 12/50
# 114/114 [==============================] - 43s 376ms/step - loss: 0.4732 - accuracy: 0.8475 - val_loss: 0.5741 - val_accuracy: 0.8497
# Epoch 13/50
# 114/114 [==============================] - 41s 362ms/step - loss: 0.4710 - accuracy: 0.8479 - val_loss: 0.5788 - val_accuracy: 0.8497
# Epoch 14/50
# 114/114 [==============================] - 41s 364ms/step - loss: 0.4667 - accuracy: 0.8481 - val_loss: 0.5771 - val_accuracy: 0.8497
# Epoch 15/50
# 114/114 [==============================] - 42s 364ms/step - loss: 0.4706 - accuracy: 0.8479 - val_loss: 0.5761 - val_accuracy: 0.8497
# Epoch 16/50
# 114/114 [==============================] - 42s 366ms/step - loss: 0.4575 - accuracy: 0.8481 - val_loss: 0.5751 - val_accuracy: 0.8497
# Epoch 17/50
# 114/114 [==============================] - 41s 363ms/step - loss: 0.4546 - accuracy: 0.8482 - val_loss: 0.5668 - val_accuracy: 0.8497
# Epoch 18/50
# 114/114 [==============================] - 43s 381ms/step - loss: 0.4630 - accuracy: 0.8481 - val_loss: 0.5712 - val_accuracy: 0.8497
# Epoch 19/50
# 114/114 [==============================] - 42s 365ms/step - loss: 0.4601 - accuracy: 0.8482 - val_loss: 0.5608 - val_accuracy: 0.8497
# Epoch 20/50
# 114/114 [==============================] - 41s 363ms/step - loss: 0.4495 - accuracy: 0.8481 - val_loss: 0.5484 - val_accuracy: 0.8497
# Epoch 21/50
# 114/114 [==============================] - 42s 365ms/step - loss: 0.4509 - accuracy: 0.8481 - val_loss: 0.5574 - val_accuracy: 0.8497
# Epoch 22/50
# 114/114 [==============================] - 41s 364ms/step - loss: 0.4527 - accuracy: 0.8481 - val_loss: 0.5510 - val_accuracy: 0.8497
# Epoch 23/50
# 114/114 [==============================] - 42s 365ms/step - loss: 0.4455 - accuracy: 0.8481 - val_loss: 0.5283 - val_accuracy: 0.8497
# Epoch 24/50
# 114/114 [==============================] - 44s 383ms/step - loss: 0.4542 - accuracy: 0.8484 - val_loss: 0.5437 - val_accuracy: 0.8497
# Epoch 25/50
# 114/114 [==============================] - 42s 366ms/step - loss: 0.4525 - accuracy: 0.8482 - val_loss: 0.5622 - val_accuracy: 0.8497
# Epoch 26/50
# 114/114 [==============================] - 42s 365ms/step - loss: 0.4459 - accuracy: 0.8482 - val_loss: 0.5828 - val_accuracy: 0.8497
# Epoch 27/50
# 114/114 [==============================] - 42s 365ms/step - loss: 0.4480 - accuracy: 0.8482 - val_loss: 0.5342 - val_accuracy: 0.8497
# Epoch 28/50
# 114/114 [==============================] - 42s 366ms/step - loss: 0.4465 - accuracy: 0.8482 - val_loss: 0.5797 - val_accuracy: 0.8497
# Epoch 29/50
# 114/114 [==============================] - 41s 363ms/step - loss: 0.4493 - accuracy: 0.8482 - val_loss: 0.5572 - val_accuracy: 0.8497
# Epoch 30/50
# 114/114 [==============================] - 43s 378ms/step - loss: 0.4476 - accuracy: 0.8482 - val_loss: 0.5443 - val_accuracy: 0.8497
# Epoch 31/50
# 114/114 [==============================] - 42s 365ms/step - loss: 0.4464 - accuracy: 0.8482 - val_loss: 0.5506 - val_accuracy: 0.8497
# Epoch 32/50
# 114/114 [==============================] - 41s 364ms/step - loss: 0.4466 - accuracy: 0.8482 - val_loss: 0.5663 - val_accuracy: 0.8497
# Epoch 33/50
# 114/114 [==============================] - 41s 362ms/step - loss: 0.4459 - accuracy: 0.8482 - val_loss: 0.5569 - val_accuracy: 0.8497
# Epoch 34/50
# 114/114 [==============================] - 41s 364ms/step - loss: 0.4418 - accuracy: 0.8482 - val_loss: 0.5354 - val_accuracy: 0.8497
# Epoch 35/50
# 114/114 [==============================] - 42s 366ms/step - loss: 0.4416 - accuracy: 0.8482 - val_loss: 0.5475 - val_accuracy: 0.8497
# Epoch 36/50
# 114/114 [==============================] - 44s 382ms/step - loss: 0.4449 - accuracy: 0.8482 - val_loss: 0.5357 - val_accuracy: 0.8497
# Epoch 37/50
# 114/114 [==============================] - 41s 364ms/step - loss: 0.4401 - accuracy: 0.8482 - val_loss: 0.5392 - val_accuracy: 0.8497
# Epoch 38/50
# 114/114 [==============================] - 41s 363ms/step - loss: 0.4401 - accuracy: 0.8482 - val_loss: 0.5231 - val_accuracy: 0.8497
# Epoch 39/50
# 114/114 [==============================] - 41s 364ms/step - loss: 0.4419 - accuracy: 0.8482 - val_loss: 0.5188 - val_accuracy: 0.8497
# Epoch 40/50
# 114/114 [==============================] - 41s 363ms/step - loss: 0.4373 - accuracy: 0.8482 - val_loss: 0.5166 - val_accuracy: 0.8497
# Epoch 41/50
# 114/114 [==============================] - 41s 362ms/step - loss: 0.4342 - accuracy: 0.8482 - val_loss: 0.5306 - val_accuracy: 0.8497
# Epoch 42/50
# 114/114 [==============================] - 41s 360ms/step - loss: 0.4344 - accuracy: 0.8482 - val_loss: 0.5540 - val_accuracy: 0.8497
# Epoch 43/50
# 114/114 [==============================] - 43s 378ms/step - loss: 0.4338 - accuracy: 0.8482 - val_loss: 0.5246 - val_accuracy: 0.8497
# Epoch 44/50
# 114/114 [==============================] - 41s 363ms/step - loss: 0.4244 - accuracy: 0.8482 - val_loss: 0.5548 - val_accuracy: 0.8497
# Epoch 45/50
# 114/114 [==============================] - 41s 363ms/step - loss: 0.4354 - accuracy: 0.8482 - val_loss: 0.5344 - val_accuracy: 0.8497
# Epoch 46/50
# 114/114 [==============================] - 42s 368ms/step - loss: 0.4285 - accuracy: 0.8482 - val_loss: 0.5627 - val_accuracy: 0.8497
# Epoch 47/50
# 114/114 [==============================] - 42s 366ms/step - loss: 0.4258 - accuracy: 0.8482 - val_loss: 0.5524 - val_accuracy: 0.8497
# Epoch 48/50
# 114/114 [==============================] - 41s 363ms/step - loss: 0.4326 - accuracy: 0.8482 - val_loss: 0.5265 - val_accuracy: 0.8497
# Epoch 49/50
# 114/114 [==============================] - 43s 380ms/step - loss: 0.4284 - accuracy: 0.8482 - val_loss: 0.5415 - val_accuracy: 0.8497
# Epoch 50/50
# 114/114 [==============================] - 41s 363ms/step - loss: 0.4292 - accuracy: 0.8482 - val_loss: 0.5611 - val_accuracy: 0.8497

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
result = model.evaluate(X_test, y_test, batch_size = 50)
print('Test Loss, Test Accuracy :', result)
# Out:
# 68/68 [==============================] - 5s 76ms/step - loss: 0.5611 - accuracy: 0.8497
# Test Loss, Test Accuracy : [0.5611473321914673, 0.8497058749198914]

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
P = model.predict(X_predict)

true = 0
for i in range(X_predict.shape[0]):
    if(np.argmax(P[i]) == np.argmax(y_true[i])):
        true = true + 1

pre_accuracy = 100 * float(true/X_predict.shape[0])        
print('Predict Accuracy: {}' .format(pre_accuracy))
# Out:
# Predict Accuracy: 84.42876047640053

# %%
import seaborn as sns
false = len(X_predict) - true

predict = [true, false]
label = ['true_predict', 'false_predict']

plt.bar(label[0], predict[0])
plt.bar(label[1], predict[1])
plt.title('Predict Accuracy')
plt.xlabel('predict')
plt.ylabel('count')
plt.legend(['true_predict', 'false_predict'], loc='upper left')
plt.show()
