# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import glob
import random
import warnings
warnings.filterwarnings(action = 'ignore')
import matplotlib.pyplot as plt
import cv2
from PIL import Image

random.seed(98)
np.random.seed(98)

# %%
breast_img = glob.glob('drive/MyDrive/Colab Notebooks/ClasesDoctorado/VisionDeMaquina/bordes/Gauss/*/**.png', recursive = True)

# %%
for imgname in breast_img[:]:
    print(imgname)

# %%
len(breast_img)
# Out:
# 13088

# %%
non_img = []
can_img = []

for img in breast_img:
    if img[-5] == '0' :
        non_img.append(img)
    
    elif img[-5] == '1' :
        can_img.append(img)

# %%
non_num = len(non_img)
can_num = len(can_img)
        
total_img_num = non_num + can_num
        
print('Number of Images in IDC (-): {}' .format(non_num))
print('Number of Images in IDC (+) : {}' .format(can_num))
print('Total Number of Images : {}' .format(total_img_num))
# Out:
# Number of Images in IDC (-): 7421
# Number of Images in IDC (+) : 5667
# Total Number of Images : 13088

# %%
from keras.preprocessing import image

plt.figure(figsize = (15, 15))

some_non = np.random.randint(0, len(non_img), 18)
some_can = np.random.randint(0, len(can_img), 18)

s = 0
for num in some_non:
    
        img = image.load_img((non_img[num]), target_size=(100, 100))
        img = image.img_to_array(img)
        
        plt.subplot(6, 6, 2*s+1)
        plt.axis('off')
        plt.title('IDC (-)')
        plt.imshow(img.astype('uint8'))
        s += 1
        
s = 1
for num in some_can:
    
        img = image.load_img((can_img[num]), target_size=(100, 100))
        img = image.img_to_array(img)
        
        plt.subplot(6, 6, 2*s)
        plt.axis('off')        
        plt.title('IDC (+)')
        plt.imshow(img.astype('uint8'))
        s += 1

# %%
from matplotlib.image import imread
import cv2

some_non_img = random.sample(non_img, len(can_img))
some_can_img = random.sample(can_img, len(can_img))

non_img_arr = []
can_img_arr = []

for img in some_non_img:
        
    n_img = cv2.imread(img, 0)
    n_img_size = cv2.resize(n_img, (50, 50), interpolation = cv2.INTER_LINEAR)
    non_img_arr.append([n_img_size, 0])
    
for img in some_can_img:
    
    c_img = cv2.imread(img, 0)
    c_img_size = cv2.resize(c_img, (50, 50), interpolation = cv2.INTER_LINEAR)
    can_img_arr.append([c_img_size, 1])

# %%
X = []
y = []

breast_img_arr = np.concatenate((non_img_arr, can_img_arr))
random.shuffle(breast_img_arr)

for feature, label in breast_img_arr:
    X.append(feature)
    y.append(label)
    
X = np.array(X)
y = np.array(y)

print('X shape : {}' .format(X.shape))
# Out:
# X shape : (11334, 50, 50)

# %%
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical

X_train, X_predict, y_train, y_true = train_test_split(X, y, test_size = 0.2, random_state = 7)

rate = 0.5
num = int(X.shape[0] * rate)

X_test = X_train[num:]
X_train = X_train[:num]

y_test = y_train[num:]
y_train = y_train[:num]

y_train = to_categorical(y_train, 2)
y_test = to_categorical(y_test, 2)
y_true = to_categorical(y_true, 2)

print('X_train shape : {}' .format(X_train.shape))
print('X_test shape : {}' .format(X_test.shape))
print('X_predict shape : {}' .format(X_predict.shape))
print('y_train shape : {}' .format(y_train.shape))
print('y_test shape : {}' .format(y_test.shape))
print('y_true shape : {}' .format(y_true.shape))
# Out:
# X_train shape : (5667, 50, 50)
# X_test shape : (3400, 50, 50)
# X_predict shape : (2267, 50, 50)
# y_train shape : (5667, 2)
# y_test shape : (3400, 2)
# y_true shape : (2267, 2)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense

model = Sequential()

model.add(Conv2D(32, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 1)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 1)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 1)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 1)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation = 'relu'))

model.add(Dropout(0.5))
model.add(Dense(2, activation = 'sigmoid'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 50, 50, 32)        320
#
#  max_pooling2d_4 (MaxPooling  (None, 25, 25, 32)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 25, 25, 32)        0
#
#  conv2d_5 (Conv2D)           (None, 25, 25, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 12, 12, 64)        0
#
#  conv2d_6 (Conv2D)           (None, 12, 12, 128)       73856
#
#  max_pooling2d_6 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  dropout_7 (Dropout)         (None, 6, 6, 128)         0
#
#  conv2d_7 (Conv2D)           (None, 6, 6, 128)         147584
#
#  max_pooling2d_7 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  dropout_8 (Dropout)         (None, 3, 3, 128)         0
#
#  flatten_1 (Flatten)         (None, 1152)              0
#
#  dense_2 (Dense)             (None, 128)               147584
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 388,098
# Trainable params: 388,098
# Non-trainable params: 0
# _________________________________________________________________

# %%
# !pip install Adam
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Adam in /usr/local/lib/python3.7/dist-packages (0.0.0.dev0)

# %%
from tensorflow.keras.optimizers import Adam

Adam = Adam(learning_rate = 0.0001)
model.compile(loss = 'binary_crossentropy', optimizer = Adam, metrics = ['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = 50, batch_size = 50)
# Out:
# Epoch 1/50
# 114/114 [==============================] - 50s 413ms/step - loss: 2.6783 - accuracy: 0.7969 - val_loss: 0.4838 - val_accuracy: 0.8435
# Epoch 2/50
# 114/114 [==============================] - 38s 331ms/step - loss: 0.5871 - accuracy: 0.8167 - val_loss: 0.5649 - val_accuracy: 0.8435
# Epoch 3/50
# 114/114 [==============================] - 38s 334ms/step - loss: 0.4901 - accuracy: 0.8315 - val_loss: 0.5757 - val_accuracy: 0.8435
# Epoch 4/50
# 114/114 [==============================] - 41s 361ms/step - loss: 0.4620 - accuracy: 0.8382 - val_loss: 0.5707 - val_accuracy: 0.8435
# Epoch 5/50
# 114/114 [==============================] - 38s 336ms/step - loss: 0.4496 - accuracy: 0.8405 - val_loss: 0.5587 - val_accuracy: 0.8435
# Epoch 6/50
# 114/114 [==============================] - 38s 335ms/step - loss: 0.4419 - accuracy: 0.8412 - val_loss: 0.5661 - val_accuracy: 0.8435
# Epoch 7/50
# 114/114 [==============================] - 38s 336ms/step - loss: 0.4353 - accuracy: 0.8426 - val_loss: 0.5420 - val_accuracy: 0.8435
# Epoch 8/50
# 114/114 [==============================] - 38s 338ms/step - loss: 0.4312 - accuracy: 0.8419 - val_loss: 0.5415 - val_accuracy: 0.8435
# Epoch 9/50
# 114/114 [==============================] - 38s 331ms/step - loss: 0.4269 - accuracy: 0.8428 - val_loss: 0.5524 - val_accuracy: 0.8435
# Epoch 10/50
# 114/114 [==============================] - 38s 334ms/step - loss: 0.4301 - accuracy: 0.8422 - val_loss: 0.5500 - val_accuracy: 0.8435
# Epoch 11/50
# 114/114 [==============================] - 38s 331ms/step - loss: 0.4222 - accuracy: 0.8433 - val_loss: 0.5481 - val_accuracy: 0.8435
# Epoch 12/50
# 114/114 [==============================] - 38s 331ms/step - loss: 0.4167 - accuracy: 0.8430 - val_loss: 0.5465 - val_accuracy: 0.8435
# Epoch 13/50
# 114/114 [==============================] - 39s 341ms/step - loss: 0.4181 - accuracy: 0.8431 - val_loss: 0.5307 - val_accuracy: 0.8435
# Epoch 14/50
# 114/114 [==============================] - 38s 330ms/step - loss: 0.4086 - accuracy: 0.8430 - val_loss: 0.5394 - val_accuracy: 0.8435
# Epoch 15/50
# 114/114 [==============================] - 38s 332ms/step - loss: 0.4087 - accuracy: 0.8430 - val_loss: 0.5444 - val_accuracy: 0.8435
# Epoch 16/50
# 114/114 [==============================] - 38s 331ms/step - loss: 0.4121 - accuracy: 0.8431 - val_loss: 0.5361 - val_accuracy: 0.8435
# Epoch 17/50
# 114/114 [==============================] - 46s 403ms/step - loss: 0.4078 - accuracy: 0.8428 - val_loss: 0.5398 - val_accuracy: 0.8435
# Epoch 18/50
# 114/114 [==============================] - 38s 331ms/step - loss: 0.4006 - accuracy: 0.8428 - val_loss: 0.5208 - val_accuracy: 0.8435
# Epoch 19/50
# 114/114 [==============================] - 38s 332ms/step - loss: 0.3974 - accuracy: 0.8433 - val_loss: 0.4965 - val_accuracy: 0.8435
# Epoch 20/50
# 114/114 [==============================] - 39s 343ms/step - loss: 0.3928 - accuracy: 0.8433 - val_loss: 0.4777 - val_accuracy: 0.8435
# Epoch 21/50
# 114/114 [==============================] - 39s 337ms/step - loss: 0.3854 - accuracy: 0.8435 - val_loss: 0.4834 - val_accuracy: 0.8435
# Epoch 22/50
# 114/114 [==============================] - 38s 336ms/step - loss: 0.3737 - accuracy: 0.8433 - val_loss: 0.5771 - val_accuracy: 0.8444
# Epoch 23/50
# 114/114 [==============================] - 38s 331ms/step - loss: 0.3555 - accuracy: 0.8445 - val_loss: 0.4168 - val_accuracy: 0.8459
# Epoch 24/50
# 114/114 [==============================] - 38s 331ms/step - loss: 0.3349 - accuracy: 0.8475 - val_loss: 0.3307 - val_accuracy: 0.8582
# Epoch 25/50
# 114/114 [==============================] - 37s 329ms/step - loss: 0.2941 - accuracy: 0.8684 - val_loss: 0.2575 - val_accuracy: 0.8538
# Epoch 26/50
# 114/114 [==============================] - 37s 329ms/step - loss: 0.2668 - accuracy: 0.8865 - val_loss: 0.3535 - val_accuracy: 0.9388
# Epoch 27/50
# 114/114 [==============================] - 38s 330ms/step - loss: 0.2426 - accuracy: 0.9038 - val_loss: 0.3334 - val_accuracy: 0.9624
# Epoch 28/50
# 114/114 [==============================] - 38s 330ms/step - loss: 0.2057 - accuracy: 0.9232 - val_loss: 0.1997 - val_accuracy: 0.9644
# Epoch 29/50
# 114/114 [==============================] - 39s 345ms/step - loss: 0.1888 - accuracy: 0.9277 - val_loss: 0.2117 - val_accuracy: 0.9694
# Epoch 30/50
# 114/114 [==============================] - 37s 329ms/step - loss: 0.1841 - accuracy: 0.9298 - val_loss: 0.3140 - val_accuracy: 0.8888
# Epoch 31/50
# 114/114 [==============================] - 37s 327ms/step - loss: 0.1663 - accuracy: 0.9381 - val_loss: 0.1763 - val_accuracy: 0.9700
# Epoch 32/50
# 114/114 [==============================] - 37s 327ms/step - loss: 0.1661 - accuracy: 0.9407 - val_loss: 0.1384 - val_accuracy: 0.9741
# Epoch 33/50
# 114/114 [==============================] - 38s 331ms/step - loss: 0.1653 - accuracy: 0.9361 - val_loss: 0.1406 - val_accuracy: 0.9718
# Epoch 34/50
# 114/114 [==============================] - 38s 330ms/step - loss: 0.1411 - accuracy: 0.9451 - val_loss: 0.1312 - val_accuracy: 0.9800
# Epoch 35/50
# 114/114 [==============================] - 38s 330ms/step - loss: 0.1446 - accuracy: 0.9481 - val_loss: 0.1239 - val_accuracy: 0.9815
# Epoch 36/50
# 114/114 [==============================] - 38s 332ms/step - loss: 0.1369 - accuracy: 0.9516 - val_loss: 0.1966 - val_accuracy: 0.9626
# Epoch 37/50
# 114/114 [==============================] - 39s 346ms/step - loss: 0.1138 - accuracy: 0.9568 - val_loss: 0.2858 - val_accuracy: 0.8803
# Epoch 38/50
# 114/114 [==============================] - 38s 331ms/step - loss: 0.1287 - accuracy: 0.9509 - val_loss: 0.0993 - val_accuracy: 0.9850
# Epoch 39/50
# 114/114 [==============================] - 38s 334ms/step - loss: 0.1081 - accuracy: 0.9594 - val_loss: 0.1052 - val_accuracy: 0.9829
# Epoch 40/50
# 114/114 [==============================] - 38s 331ms/step - loss: 0.1120 - accuracy: 0.9599 - val_loss: 0.1462 - val_accuracy: 0.9650
# Epoch 41/50
# 114/114 [==============================] - 38s 330ms/step - loss: 0.0926 - accuracy: 0.9649 - val_loss: 0.1373 - val_accuracy: 0.9612
# Epoch 42/50
# 114/114 [==============================] - 38s 332ms/step - loss: 0.1007 - accuracy: 0.9631 - val_loss: 0.4871 - val_accuracy: 0.7371
# Epoch 43/50
# 114/114 [==============================] - 38s 335ms/step - loss: 0.1210 - accuracy: 0.9546 - val_loss: 0.0689 - val_accuracy: 0.9856
# Epoch 44/50
# 114/114 [==============================] - 38s 333ms/step - loss: 0.0920 - accuracy: 0.9658 - val_loss: 0.1742 - val_accuracy: 0.9359
# Epoch 45/50
# 114/114 [==============================] - 38s 332ms/step - loss: 0.0899 - accuracy: 0.9654 - val_loss: 0.1115 - val_accuracy: 0.9697
# Epoch 46/50
# 114/114 [==============================] - 40s 348ms/step - loss: 0.0880 - accuracy: 0.9705 - val_loss: 0.0766 - val_accuracy: 0.9853
# Epoch 47/50
# 114/114 [==============================] - 38s 331ms/step - loss: 0.0903 - accuracy: 0.9672 - val_loss: 0.2124 - val_accuracy: 0.9168
# Epoch 48/50
# 114/114 [==============================] - 38s 331ms/step - loss: 0.0746 - accuracy: 0.9716 - val_loss: 0.0643 - val_accuracy: 0.9853
# Epoch 49/50
# 114/114 [==============================] - 38s 331ms/step - loss: 0.0685 - accuracy: 0.9764 - val_loss: 0.1552 - val_accuracy: 0.9385
# Epoch 50/50
# 114/114 [==============================] - 38s 332ms/step - loss: 0.0713 - accuracy: 0.9744 - val_loss: 0.0442 - val_accuracy: 0.9903

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
result = model.evaluate(X_test, y_test, batch_size = 50)
print('Test Loss, Test Accuracy :', result)
# Out:
# 68/68 [==============================] - 5s 70ms/step - loss: 0.0442 - accuracy: 0.9903
# Test Loss, Test Accuracy : [0.044163722544908524, 0.9902940988540649]

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
P = model.predict(X_predict)

true = 0
for i in range(X_predict.shape[0]):
    if(np.argmax(P[i]) == np.argmax(y_true[i])):
        true = true + 1

pre_accuracy = 100 * float(true/X_predict.shape[0])        
print('Predict Accuracy: {}' .format(pre_accuracy))
# Out:
# Predict Accuracy: 98.4561093956771

# %%
import seaborn as sns
false = len(X_predict) - true

predict = [true, false]
label = ['true_predict', 'false_predict']

plt.bar(label[0], predict[0])
plt.bar(label[1], predict[1])
plt.title('Predict Accuracy')
plt.xlabel('predict')
plt.ylabel('count')
plt.legend(['true_predict', 'false_predict'], loc='upper left')
plt.show()
