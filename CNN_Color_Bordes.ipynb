# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import glob
import random
import warnings
warnings.filterwarnings(action = 'ignore')
import matplotlib.pyplot as plt

from PIL import Image

random.seed(98)
np.random.seed(98)

# %%
#breast_img = glob.glob('/content/drive/MyDrive/Visión de Máquina /Entrega/BancoImagenes/10272/**/*.png', recursive = True)
breast_img = glob.glob('/content/drive/MyDrive/BancoImagenes/BG02-12/**/*.png', recursive = True)
#breast_img1 = glob.glob('/content/drive/MyDrive/BancoImagenes/Color/**/*.png', recursive = True)

# %%
len(breast_img)
# Out:
# 13088

# %%
for imgname in breast_img[:4]:
    print(imgname)
# Out:
# /content/drive/MyDrive/BancoImagenes/BG02-12/02/image64210.png
# /content/drive/MyDrive/BancoImagenes/BG02-12/02/image64220.png
# /content/drive/MyDrive/BancoImagenes/BG02-12/02/image64230.png
# /content/drive/MyDrive/BancoImagenes/BG02-12/02/image64240.png

# %%
non_img = []
can_img = []

for img in breast_img:
    if img[-5] == '0' :
        non_img.append(img)
    
    elif img[-5] == '1' :
        can_img.append(img)

# %%
non_num = len(non_img)
can_num = len(can_img)
        
total_img_num = non_num + can_num
        
print('Number of Images in IDC (-): {}' .format(non_num))
print('Number of Images in IDC (+) : {}' .format(can_num))
print('Total Number of Images : {}' .format(total_img_num))
# Out:
# Number of Images in IDC (-): 7421
# Number of Images in IDC (+) : 5667
# Total Number of Images : 13088

# %%
from keras.preprocessing import image

plt.figure(figsize = (15, 15))

some_non = np.random.randint(0, len(non_img), 18)
some_can = np.random.randint(0, len(can_img), 18)

s = 0
for num in some_non:
    
        img = image.load_img((non_img[num]), target_size=(100, 100))
        img = image.img_to_array(img)
        
        plt.subplot(6, 6, 2*s+1)
        plt.axis('off')
        plt.title('IDC (-)')
        plt.imshow(img.astype('uint8'))
        s += 1
        
s = 1
for num in some_can:
    
        img = image.load_img((can_img[num]), target_size=(100, 100))
        img = image.img_to_array(img)
        
        plt.subplot(6, 6, 2*s)
        plt.axis('off')        
        plt.title('IDC (+)')
        plt.imshow(img.astype('uint8'))
        s += 1

# %%
from matplotlib.image import imread
import cv2

some_non_img = random.sample(non_img, len(non_img))
some_can_img = random.sample(can_img, len(can_img))

non_img_arr = []
can_img_arr = []

for img in some_non_img:
        
    n_img = cv2.imread(img, cv2.IMREAD_COLOR)
    n_img_size = cv2.resize(n_img, (50, 50), interpolation = cv2.INTER_LINEAR)
    non_img_arr.append([n_img_size, 0])
    
for img in some_can_img:
    
    c_img = cv2.imread(img, cv2.IMREAD_COLOR)
    c_img_size = cv2.resize(c_img, (50, 50), interpolation = cv2.INTER_LINEAR)
    can_img_arr.append([c_img_size, 1])

# %%
X = []
y = []

breast_img_arr = np.concatenate((non_img_arr, can_img_arr))
random.shuffle(breast_img_arr)

for feature, label in breast_img_arr:
    X.append(feature)
    y.append(label)
    
X = np.array(X)
y = np.array(y)

print('X shape : {}' .format(X.shape))
# Out:
# X shape : (13088, 50, 50, 3)

# %%
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical

X_train, X_predict, y_train, y_true = train_test_split(X, y, test_size = 0.2, random_state = 7)

rate = 0.5
num = int(X.shape[0] * rate)

X_test = X_train[num:]
X_train = X_train[:num]

y_test = y_train[num:]
y_train = y_train[:num]

y_train = to_categorical(y_train, 2)
y_test = to_categorical(y_test, 2)
y_true = to_categorical(y_true, 2)

print('X_train shape : {}' .format(X_train.shape))
print('X_test shape : {}' .format(X_test.shape))
print('X_predict shape : {}' .format(X_predict.shape))
print('y_train shape : {}' .format(y_train.shape))
print('y_test shape : {}' .format(y_test.shape))
print('y_true shape : {}' .format(y_true.shape))
# Out:
# X_train shape : (6544, 50, 50, 3)
# X_test shape : (3926, 50, 50, 3)
# X_predict shape : (2618, 50, 50, 3)
# y_train shape : (6544, 2)
# y_test shape : (3926, 2)
# y_true shape : (2618, 2)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense

model = Sequential()

model.add(Conv2D(32, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 3)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 3)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 3)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 3)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation = 'relu'))

model.add(Dropout(0.5))
model.add(Dense(2, activation = 'sigmoid'))

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 50, 50, 32)        896
#
#  max_pooling2d_16 (MaxPoolin  (None, 25, 25, 32)       0
#  g2D)
#
#  dropout_20 (Dropout)        (None, 25, 25, 32)        0
#
#  conv2d_17 (Conv2D)          (None, 25, 25, 64)        18496
#
#  max_pooling2d_17 (MaxPoolin  (None, 12, 12, 64)       0
#  g2D)
#
#  dropout_21 (Dropout)        (None, 12, 12, 64)        0
#
#  conv2d_18 (Conv2D)          (None, 12, 12, 128)       73856
#
#  max_pooling2d_18 (MaxPoolin  (None, 6, 6, 128)        0
#  g2D)
#
#  dropout_22 (Dropout)        (None, 6, 6, 128)         0
#
#  conv2d_19 (Conv2D)          (None, 6, 6, 128)         147584
#
#  max_pooling2d_19 (MaxPoolin  (None, 3, 3, 128)        0
#  g2D)
#
#  dropout_23 (Dropout)        (None, 3, 3, 128)         0
#
#  flatten_4 (Flatten)         (None, 1152)              0
#
#  dense_8 (Dense)             (None, 128)               147584
#
#  dropout_24 (Dropout)        (None, 128)               0
#
#  dense_9 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 388,674
# Trainable params: 388,674
# Non-trainable params: 0
# _________________________________________________________________

# %%
# !pip install Adam
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Adam in /usr/local/lib/python3.7/dist-packages (0.0.0.dev0)

# %%
from tensorflow.keras.optimizers import Adam

Adam = Adam(learning_rate = 0.0001)
model.compile(loss = 'binary_crossentropy', optimizer = Adam, metrics = ['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = 50, batch_size = 50)
# Out:
# Epoch 1/50
# 131/131 [==============================] - 62s 468ms/step - loss: 3.8741 - accuracy: 0.8585 - val_loss: 0.3982 - val_accuracy: 0.8907
# Epoch 2/50
# 131/131 [==============================] - 51s 390ms/step - loss: 0.6104 - accuracy: 0.8695 - val_loss: 0.5238 - val_accuracy: 0.8907
# Epoch 3/50
# 131/131 [==============================] - 50s 381ms/step - loss: 0.4431 - accuracy: 0.8816 - val_loss: 0.5323 - val_accuracy: 0.8907
# Epoch 4/50
# 131/131 [==============================] - 49s 373ms/step - loss: 0.4089 - accuracy: 0.8871 - val_loss: 0.5542 - val_accuracy: 0.8907
# Epoch 5/50
# 131/131 [==============================] - 49s 372ms/step - loss: 0.3859 - accuracy: 0.8901 - val_loss: 0.5334 - val_accuracy: 0.8907
# Epoch 6/50
# 131/131 [==============================] - 49s 373ms/step - loss: 0.3811 - accuracy: 0.8910 - val_loss: 0.5513 - val_accuracy: 0.8907
# Epoch 7/50
# 131/131 [==============================] - 51s 388ms/step - loss: 0.3711 - accuracy: 0.8918 - val_loss: 0.5545 - val_accuracy: 0.8907
# Epoch 8/50
# 131/131 [==============================] - 49s 372ms/step - loss: 0.3561 - accuracy: 0.8918 - val_loss: 0.5543 - val_accuracy: 0.8907
# Epoch 9/50
# 131/131 [==============================] - 49s 372ms/step - loss: 0.3437 - accuracy: 0.8926 - val_loss: 0.5274 - val_accuracy: 0.8910
# Epoch 10/50
# 131/131 [==============================] - 48s 370ms/step - loss: 0.3330 - accuracy: 0.8918 - val_loss: 0.5158 - val_accuracy: 0.8951
# Epoch 11/50
# 131/131 [==============================] - 48s 370ms/step - loss: 0.3130 - accuracy: 0.8926 - val_loss: 0.5177 - val_accuracy: 0.8971
# Epoch 12/50
# 131/131 [==============================] - 50s 384ms/step - loss: 0.3145 - accuracy: 0.8949 - val_loss: 0.5368 - val_accuracy: 0.8958
# Epoch 13/50
# 131/131 [==============================] - 48s 370ms/step - loss: 0.3047 - accuracy: 0.8930 - val_loss: 0.4380 - val_accuracy: 0.8930
# Epoch 14/50
# 131/131 [==============================] - 48s 370ms/step - loss: 0.3067 - accuracy: 0.8947 - val_loss: 0.5040 - val_accuracy: 0.9022
# Epoch 15/50
# 131/131 [==============================] - 48s 368ms/step - loss: 0.3013 - accuracy: 0.8982 - val_loss: 0.5076 - val_accuracy: 0.9068
# Epoch 16/50
# 131/131 [==============================] - 48s 368ms/step - loss: 0.2982 - accuracy: 0.8976 - val_loss: 0.5987 - val_accuracy: 0.8935
# Epoch 17/50
# 131/131 [==============================] - 50s 385ms/step - loss: 0.2917 - accuracy: 0.8996 - val_loss: 0.4508 - val_accuracy: 0.9114
# Epoch 18/50
# 131/131 [==============================] - 49s 371ms/step - loss: 0.2839 - accuracy: 0.9074 - val_loss: 0.4391 - val_accuracy: 0.9083
# Epoch 19/50
# 131/131 [==============================] - 48s 369ms/step - loss: 0.2788 - accuracy: 0.9112 - val_loss: 0.4982 - val_accuracy: 0.8963
# Epoch 20/50
# 131/131 [==============================] - 48s 369ms/step - loss: 0.2775 - accuracy: 0.9126 - val_loss: 0.5112 - val_accuracy: 0.8752
# Epoch 21/50
# 131/131 [==============================] - 48s 370ms/step - loss: 0.2734 - accuracy: 0.9118 - val_loss: 0.4721 - val_accuracy: 0.8966
# Epoch 22/50
# 131/131 [==============================] - 51s 387ms/step - loss: 0.2648 - accuracy: 0.9137 - val_loss: 0.5173 - val_accuracy: 0.8711
# Epoch 23/50
# 131/131 [==============================] - 48s 369ms/step - loss: 0.2613 - accuracy: 0.9158 - val_loss: 0.4771 - val_accuracy: 0.9035
# Epoch 24/50
# 131/131 [==============================] - 48s 370ms/step - loss: 0.2565 - accuracy: 0.9172 - val_loss: 0.5071 - val_accuracy: 0.8971
# Epoch 25/50
# 131/131 [==============================] - 48s 370ms/step - loss: 0.2498 - accuracy: 0.9187 - val_loss: 0.4886 - val_accuracy: 0.8739
# Epoch 26/50
# 131/131 [==============================] - 49s 371ms/step - loss: 0.2474 - accuracy: 0.9187 - val_loss: 0.4519 - val_accuracy: 0.8846
# Epoch 27/50
# 131/131 [==============================] - 51s 386ms/step - loss: 0.2441 - accuracy: 0.9216 - val_loss: 0.3995 - val_accuracy: 0.8976
# Epoch 28/50
# 131/131 [==============================] - 48s 369ms/step - loss: 0.2294 - accuracy: 0.9219 - val_loss: 0.5384 - val_accuracy: 0.7970
# Epoch 29/50
# 131/131 [==============================] - 48s 369ms/step - loss: 0.2225 - accuracy: 0.9234 - val_loss: 0.4213 - val_accuracy: 0.8574
# Epoch 30/50
# 131/131 [==============================] - 48s 368ms/step - loss: 0.2223 - accuracy: 0.9248 - val_loss: 0.4620 - val_accuracy: 0.8355
# Epoch 31/50
# 131/131 [==============================] - 48s 367ms/step - loss: 0.2184 - accuracy: 0.9248 - val_loss: 0.4477 - val_accuracy: 0.8551
# Epoch 32/50
# 131/131 [==============================] - 48s 369ms/step - loss: 0.2184 - accuracy: 0.9271 - val_loss: 0.5834 - val_accuracy: 0.7580
# Epoch 33/50
# 131/131 [==============================] - 50s 383ms/step - loss: 0.2016 - accuracy: 0.9317 - val_loss: 0.3465 - val_accuracy: 0.8849
# Epoch 34/50
# 131/131 [==============================] - 48s 370ms/step - loss: 0.2034 - accuracy: 0.9323 - val_loss: 0.3357 - val_accuracy: 0.8897
# Epoch 35/50
# 131/131 [==============================] - 48s 368ms/step - loss: 0.1967 - accuracy: 0.9367 - val_loss: 0.4536 - val_accuracy: 0.8207
# Epoch 36/50
# 131/131 [==============================] - 48s 368ms/step - loss: 0.1948 - accuracy: 0.9355 - val_loss: 0.3446 - val_accuracy: 0.8851
# Epoch 37/50
# 131/131 [==============================] - 48s 368ms/step - loss: 0.1929 - accuracy: 0.9384 - val_loss: 0.4928 - val_accuracy: 0.7886
# Epoch 38/50
# 131/131 [==============================] - 50s 383ms/step - loss: 0.1905 - accuracy: 0.9412 - val_loss: 0.2434 - val_accuracy: 0.9307
# Epoch 39/50
# 131/131 [==============================] - 48s 368ms/step - loss: 0.1824 - accuracy: 0.9410 - val_loss: 0.2259 - val_accuracy: 0.9315
# Epoch 40/50
# 131/131 [==============================] - 48s 369ms/step - loss: 0.1817 - accuracy: 0.9441 - val_loss: 0.4403 - val_accuracy: 0.8416
# Epoch 41/50
# 131/131 [==============================] - 48s 368ms/step - loss: 0.1737 - accuracy: 0.9430 - val_loss: 0.2656 - val_accuracy: 0.9124
# Epoch 42/50
# 131/131 [==============================] - 48s 367ms/step - loss: 0.1718 - accuracy: 0.9471 - val_loss: 0.2463 - val_accuracy: 0.9228
# Epoch 43/50
# 131/131 [==============================] - 50s 382ms/step - loss: 0.1741 - accuracy: 0.9445 - val_loss: 0.3165 - val_accuracy: 0.8915
# Epoch 44/50
# 131/131 [==============================] - 48s 367ms/step - loss: 0.1636 - accuracy: 0.9468 - val_loss: 0.2134 - val_accuracy: 0.9330
# Epoch 45/50
# 131/131 [==============================] - 48s 367ms/step - loss: 0.1645 - accuracy: 0.9468 - val_loss: 0.2837 - val_accuracy: 0.9159
# Epoch 46/50
# 131/131 [==============================] - 49s 371ms/step - loss: 0.1717 - accuracy: 0.9448 - val_loss: 0.1970 - val_accuracy: 0.9460
# Epoch 47/50
# 131/131 [==============================] - 48s 369ms/step - loss: 0.1628 - accuracy: 0.9491 - val_loss: 0.2097 - val_accuracy: 0.9429
# Epoch 48/50
# 131/131 [==============================] - 50s 381ms/step - loss: 0.1572 - accuracy: 0.9482 - val_loss: 0.2168 - val_accuracy: 0.9361
# Epoch 49/50
# 131/131 [==============================] - 48s 365ms/step - loss: 0.1637 - accuracy: 0.9470 - val_loss: 0.2741 - val_accuracy: 0.9238
# Epoch 50/50
# 131/131 [==============================] - 48s 363ms/step - loss: 0.1526 - accuracy: 0.9505 - val_loss: 0.1598 - val_accuracy: 0.9508

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
result = model.evaluate(X_test, y_test, batch_size = 50)
print('Test Loss, Test Accuracy :', result)
# Out:
# 79/79 [==============================] - 9s 115ms/step - loss: 0.1598 - accuracy: 0.9508
# Test Loss, Test Accuracy : [0.15983577072620392, 0.9508405327796936]

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
P = model.predict(X_predict)

true = 0
for i in range(X_predict.shape[0]):
    if(np.argmax(P[i]) == np.argmax(y_true[i])):
        true = true + 1

pre_accuracy = 100 * float(true/X_predict.shape[0])        
print('Predict Accuracy: {}' .format(pre_accuracy))
# Out:
# Predict Accuracy: 94.9579831932773

# %%
import seaborn as sns
false = len(X_predict) - true

predict = [true, false]
label = ['true_predict', 'false_predict']

plt.bar(label[0], predict[0])
plt.bar(label[1], predict[1])
plt.title('Predict Accuracy')
plt.xlabel('predict')
plt.ylabel('count')
plt.legend(['true_predict', 'false_predict'], loc='upper left')
plt.show()
