# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import glob
import random
import warnings
warnings.filterwarnings(action = 'ignore')
import matplotlib.pyplot as plt
import cv2
from PIL import Image

random.seed(98)
np.random.seed(98)

# %%
breast_img = glob.glob('drive/MyDrive/Colab Notebooks/ClasesDoctorado/VisionDeMaquina/bordes/Gauss/*/**.png', recursive = True)

# %%
for imgname in breast_img[:]:
    print(imgname)

# %%
len(breast_img)
# Out:
# 13089

# %%
non_img = []
can_img = []

for img in breast_img:
    if img[-5] == '0' :
        non_img.append(img)
    
    elif img[-5] == '1' :
        can_img.append(img)

# %%
non_num = len(non_img)
can_num = len(can_img)
        
total_img_num = non_num + can_num
        
print('Number of Images in IDC (-): {}' .format(non_num))
print('Number of Images in IDC (+) : {}' .format(can_num))
print('Total Number of Images : {}' .format(total_img_num))
# Out:
# Number of Images in IDC (-): 7422
# Number of Images in IDC (+) : 5667
# Total Number of Images : 13089

# %%
from keras.preprocessing import image

plt.figure(figsize = (15, 15))

some_non = np.random.randint(0, len(non_img), 18)
some_can = np.random.randint(0, len(can_img), 18)

s = 0
for num in some_non:
    
        img = image.load_img((non_img[num]), target_size=(100, 100))
        img = image.img_to_array(img)
        
        plt.subplot(6, 6, 2*s+1)
        plt.axis('off')
        plt.title('IDC (-)')
        plt.imshow(img.astype('uint8'))
        s += 1
        
s = 1
for num in some_can:
    
        img = image.load_img((can_img[num]), target_size=(100, 100))
        img = image.img_to_array(img)
        
        plt.subplot(6, 6, 2*s)
        plt.axis('off')        
        plt.title('IDC (+)')
        plt.imshow(img.astype('uint8'))
        s += 1

# %%
from matplotlib.image import imread
import cv2

some_non_img = random.sample(non_img, len(can_img))
some_can_img = random.sample(can_img, len(can_img))

non_img_arr = []
can_img_arr = []

for img in some_non_img:
        
    n_img = cv2.imread(img, 0)
    n_img_size = cv2.resize(n_img, (50, 50), interpolation = cv2.INTER_LINEAR)
    non_img_arr.append([n_img_size, 0])
    
for img in some_can_img:
    
    c_img = cv2.imread(img, 0)
    c_img_size = cv2.resize(c_img, (50, 50), interpolation = cv2.INTER_LINEAR)
    can_img_arr.append([c_img_size, 1])

# %%
X = []
y = []

breast_img_arr = np.concatenate((non_img_arr, can_img_arr))
random.shuffle(breast_img_arr)

for feature, label in breast_img_arr:
    X.append(feature)
    y.append(label)
    
X = np.array(X)
y = np.array(y)

print('X shape : {}' .format(X.shape))
# Out:
# X shape : (11334, 50, 50)

# %%
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical

X_train, X_predict, y_train, y_true = train_test_split(X, y, test_size = 0.2, random_state = 7)

rate = 0.5
num = int(X.shape[0] * rate)

X_test = X_train[num:]
X_train = X_train[:num]

y_test = y_train[num:]
y_train = y_train[:num]

y_train = to_categorical(y_train, 2)
y_test = to_categorical(y_test, 2)
y_true = to_categorical(y_true, 2)

print('X_train shape : {}' .format(X_train.shape))
print('X_test shape : {}' .format(X_test.shape))
print('X_predict shape : {}' .format(X_predict.shape))
print('y_train shape : {}' .format(y_train.shape))
print('y_test shape : {}' .format(y_test.shape))
print('y_true shape : {}' .format(y_true.shape))
# Out:
# X_train shape : (5667, 50, 50)
# X_test shape : (3400, 50, 50)
# X_predict shape : (2267, 50, 50)
# y_train shape : (5667, 2)
# y_test shape : (3400, 2)
# y_true shape : (2267, 2)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense

model = Sequential()

model.add(Conv2D(32, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 1)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 1)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 1)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), padding = 'same', activation = 'relu', input_shape = (50, 50, 1)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation = 'relu'))

model.add(Dropout(0.5))
model.add(Dense(2, activation = 'sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 50, 50, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 25, 25, 32)       0
#  )
#
#  dropout (Dropout)           (None, 25, 25, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 25, 25, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 128)         0
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 128)         147584
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 3, 3, 128)         0
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 128)               147584
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 388,098
# Trainable params: 388,098
# Non-trainable params: 0
# _________________________________________________________________

# %%
# !pip install Adam
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Adam
#   Downloading adam-0.0.0.dev0-py2.py3-none-any.whl (2.6 kB)
# Installing collected packages: Adam
# Successfully installed Adam-0.0.0.dev0

# %%
from tensorflow.keras.optimizers import Adam

Adam = Adam(learning_rate = 0.0001)
model.compile(loss = 'binary_crossentropy', optimizer = Adam, metrics = ['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = 60, batch_size = 50)
# Out:
# Epoch 1/60
# 114/114 [==============================] - 42s 370ms/step - loss: 0.0811 - accuracy: 0.9728 - val_loss: 0.0745 - val_accuracy: 0.9818
# Epoch 2/60
# 114/114 [==============================] - 43s 379ms/step - loss: 0.0839 - accuracy: 0.9684 - val_loss: 0.4619 - val_accuracy: 0.7544
# Epoch 3/60
# 114/114 [==============================] - 41s 357ms/step - loss: 0.0779 - accuracy: 0.9704 - val_loss: 0.4332 - val_accuracy: 0.7809
# Epoch 4/60
# 114/114 [==============================] - 41s 358ms/step - loss: 0.0857 - accuracy: 0.9707 - val_loss: 0.1626 - val_accuracy: 0.9374
# Epoch 5/60
# 114/114 [==============================] - 41s 360ms/step - loss: 0.0683 - accuracy: 0.9744 - val_loss: 0.2738 - val_accuracy: 0.8741
# Epoch 6/60
# 114/114 [==============================] - 41s 360ms/step - loss: 0.0697 - accuracy: 0.9751 - val_loss: 0.2023 - val_accuracy: 0.9118
# Epoch 7/60
# 114/114 [==============================] - 43s 377ms/step - loss: 0.0710 - accuracy: 0.9764 - val_loss: 0.1502 - val_accuracy: 0.9415
# Epoch 8/60
# 114/114 [==============================] - 41s 360ms/step - loss: 0.0769 - accuracy: 0.9739 - val_loss: 0.2767 - val_accuracy: 0.8762
# Epoch 9/60
# 114/114 [==============================] - 41s 359ms/step - loss: 0.0692 - accuracy: 0.9758 - val_loss: 0.2134 - val_accuracy: 0.9091
# Epoch 10/60
# 114/114 [==============================] - 41s 359ms/step - loss: 0.0752 - accuracy: 0.9723 - val_loss: 0.2342 - val_accuracy: 0.9026
# Epoch 11/60
# 114/114 [==============================] - 41s 361ms/step - loss: 0.0589 - accuracy: 0.9808 - val_loss: 0.1465 - val_accuracy: 0.9432
# Epoch 12/60
# 114/114 [==============================] - 43s 376ms/step - loss: 0.0576 - accuracy: 0.9794 - val_loss: 0.1575 - val_accuracy: 0.9300
# Epoch 13/60
# 114/114 [==============================] - 41s 360ms/step - loss: 0.0609 - accuracy: 0.9772 - val_loss: 0.0466 - val_accuracy: 0.9871
# Epoch 14/60
# 114/114 [==============================] - 41s 360ms/step - loss: 0.0751 - accuracy: 0.9723 - val_loss: 0.0863 - val_accuracy: 0.9724
# Epoch 15/60
# 114/114 [==============================] - 41s 361ms/step - loss: 0.0738 - accuracy: 0.9709 - val_loss: 0.3418 - val_accuracy: 0.8365
# Epoch 16/60
# 114/114 [==============================] - 41s 359ms/step - loss: 0.0678 - accuracy: 0.9753 - val_loss: 0.3240 - val_accuracy: 0.8426
# Epoch 17/60
# 114/114 [==============================] - 41s 359ms/step - loss: 0.0525 - accuracy: 0.9795 - val_loss: 0.2250 - val_accuracy: 0.9024
# Epoch 18/60
# 114/114 [==============================] - 43s 374ms/step - loss: 0.0488 - accuracy: 0.9832 - val_loss: 0.1592 - val_accuracy: 0.9324
# Epoch 19/60
# 114/114 [==============================] - 41s 358ms/step - loss: 0.0551 - accuracy: 0.9808 - val_loss: 0.0518 - val_accuracy: 0.9850
# Epoch 20/60
# 114/114 [==============================] - 41s 358ms/step - loss: 0.0475 - accuracy: 0.9820 - val_loss: 0.5476 - val_accuracy: 0.7547
# Epoch 21/60
# 114/114 [==============================] - 43s 375ms/step - loss: 0.0779 - accuracy: 0.9709 - val_loss: 0.2229 - val_accuracy: 0.9053
# Epoch 22/60
# 114/114 [==============================] - 41s 358ms/step - loss: 0.0405 - accuracy: 0.9864 - val_loss: 0.1512 - val_accuracy: 0.9318
# Epoch 23/60
# 114/114 [==============================] - 41s 359ms/step - loss: 0.0409 - accuracy: 0.9846 - val_loss: 0.2172 - val_accuracy: 0.9047
# Epoch 24/60
# 114/114 [==============================] - 41s 357ms/step - loss: 0.0460 - accuracy: 0.9832 - val_loss: 0.1919 - val_accuracy: 0.9185
# Epoch 25/60
# 114/114 [==============================] - 41s 357ms/step - loss: 0.0670 - accuracy: 0.9748 - val_loss: 0.1627 - val_accuracy: 0.9294
# Epoch 26/60
# 114/114 [==============================] - 41s 358ms/step - loss: 0.0427 - accuracy: 0.9859 - val_loss: 0.1800 - val_accuracy: 0.9226
# Epoch 27/60
# 114/114 [==============================] - 41s 358ms/step - loss: 0.0397 - accuracy: 0.9848 - val_loss: 0.1150 - val_accuracy: 0.9535
# Epoch 28/60
# 114/114 [==============================] - 43s 376ms/step - loss: 0.0555 - accuracy: 0.9794 - val_loss: 0.2916 - val_accuracy: 0.8671
# Epoch 29/60
# 114/114 [==============================] - 41s 362ms/step - loss: 0.0490 - accuracy: 0.9813 - val_loss: 0.1852 - val_accuracy: 0.9224
# Epoch 30/60
# 114/114 [==============================] - 41s 362ms/step - loss: 0.0387 - accuracy: 0.9864 - val_loss: 0.5825 - val_accuracy: 0.7391
# Epoch 31/60
# 114/114 [==============================] - 41s 362ms/step - loss: 0.0676 - accuracy: 0.9748 - val_loss: 0.1804 - val_accuracy: 0.9282
# Epoch 32/60
# 114/114 [==============================] - 41s 359ms/step - loss: 0.0368 - accuracy: 0.9871 - val_loss: 0.0596 - val_accuracy: 0.9812
# Epoch 33/60
# 114/114 [==============================] - 43s 375ms/step - loss: 0.0488 - accuracy: 0.9822 - val_loss: 0.0913 - val_accuracy: 0.9624
# Epoch 34/60
# 114/114 [==============================] - 41s 359ms/step - loss: 0.0421 - accuracy: 0.9868 - val_loss: 0.4685 - val_accuracy: 0.7868
# Epoch 35/60
# 114/114 [==============================] - 41s 359ms/step - loss: 0.0432 - accuracy: 0.9852 - val_loss: 0.1114 - val_accuracy: 0.9559
# Epoch 36/60
# 114/114 [==============================] - 41s 358ms/step - loss: 0.0451 - accuracy: 0.9841 - val_loss: 0.7873 - val_accuracy: 0.6424
# Epoch 37/60
# 114/114 [==============================] - 41s 360ms/step - loss: 0.0310 - accuracy: 0.9896 - val_loss: 0.3141 - val_accuracy: 0.8585
# Epoch 38/60
# 114/114 [==============================] - 43s 376ms/step - loss: 0.0410 - accuracy: 0.9843 - val_loss: 0.3700 - val_accuracy: 0.8374
# Epoch 39/60
# 114/114 [==============================] - 41s 360ms/step - loss: 0.0313 - accuracy: 0.9899 - val_loss: 0.1996 - val_accuracy: 0.9147
# Epoch 40/60
# 114/114 [==============================] - 41s 359ms/step - loss: 0.0377 - accuracy: 0.9875 - val_loss: 1.1084 - val_accuracy: 0.5624
# Epoch 41/60
# 114/114 [==============================] - 41s 360ms/step - loss: 0.0397 - accuracy: 0.9845 - val_loss: 0.3901 - val_accuracy: 0.8259
# Epoch 42/60
# 114/114 [==============================] - 41s 360ms/step - loss: 0.0395 - accuracy: 0.9843 - val_loss: 0.7517 - val_accuracy: 0.6638
# Epoch 43/60
# 114/114 [==============================] - 43s 376ms/step - loss: 0.0362 - accuracy: 0.9875 - val_loss: 0.7320 - val_accuracy: 0.6862
# Epoch 44/60
# 114/114 [==============================] - 41s 359ms/step - loss: 0.0322 - accuracy: 0.9892 - val_loss: 0.3082 - val_accuracy: 0.8618
# Epoch 45/60
# 114/114 [==============================] - 41s 359ms/step - loss: 0.0326 - accuracy: 0.9894 - val_loss: 0.8221 - val_accuracy: 0.6565
# Epoch 46/60
# 114/114 [==============================] - 41s 361ms/step - loss: 0.0453 - accuracy: 0.9841 - val_loss: 0.4022 - val_accuracy: 0.8244
# Epoch 47/60
# 114/114 [==============================] - 41s 360ms/step - loss: 0.0335 - accuracy: 0.9864 - val_loss: 0.3008 - val_accuracy: 0.8656
# Epoch 48/60
# 114/114 [==============================] - 43s 375ms/step - loss: 0.0561 - accuracy: 0.9809 - val_loss: 0.1957 - val_accuracy: 0.9091
# Epoch 49/60
# 114/114 [==============================] - 41s 359ms/step - loss: 0.0278 - accuracy: 0.9892 - val_loss: 0.3052 - val_accuracy: 0.8671
# Epoch 50/60
# 114/114 [==============================] - 41s 360ms/step - loss: 0.0312 - accuracy: 0.9887 - val_loss: 0.5491 - val_accuracy: 0.7721
# Epoch 51/60
# 114/114 [==============================] - 42s 365ms/step - loss: 0.0258 - accuracy: 0.9908 - val_loss: 0.2576 - val_accuracy: 0.8868
# Epoch 52/60
# 114/114 [==============================] - 42s 365ms/step - loss: 0.0360 - accuracy: 0.9868 - val_loss: 0.4135 - val_accuracy: 0.8235
# Epoch 53/60
# 114/114 [==============================] - 42s 373ms/step - loss: 0.0363 - accuracy: 0.9892 - val_loss: 0.3200 - val_accuracy: 0.8579
# Epoch 54/60
# 114/114 [==============================] - 43s 372ms/step - loss: 0.0377 - accuracy: 0.9857 - val_loss: 0.3807 - val_accuracy: 0.8368
# Epoch 55/60
# 114/114 [==============================] - 41s 360ms/step - loss: 0.0360 - accuracy: 0.9880 - val_loss: 0.1168 - val_accuracy: 0.9532
# Epoch 56/60
# 114/114 [==============================] - 41s 360ms/step - loss: 0.0295 - accuracy: 0.9901 - val_loss: 0.9261 - val_accuracy: 0.6591
# Epoch 57/60
# 114/114 [==============================] - 41s 361ms/step - loss: 0.0231 - accuracy: 0.9917 - val_loss: 0.7600 - val_accuracy: 0.7174
# Epoch 58/60
# 114/114 [==============================] - 43s 377ms/step - loss: 0.0259 - accuracy: 0.9898 - val_loss: 0.6317 - val_accuracy: 0.7638
# Epoch 59/60
# 114/114 [==============================] - 41s 359ms/step - loss: 0.0202 - accuracy: 0.9935 - val_loss: 0.6583 - val_accuracy: 0.7582
# Epoch 60/60
# 114/114 [==============================] - 41s 361ms/step - loss: 0.0246 - accuracy: 0.9917 - val_loss: 1.1573 - val_accuracy: 0.6044

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
result = model.evaluate(X_test, y_test, batch_size = 50)
print('Test Loss, Test Accuracy :', result)
# Out:
# 68/68 [==============================] - 10s 154ms/step - loss: 0.1931 - accuracy: 0.9209
# Test Loss, Test Accuracy : [0.19313976168632507, 0.9208823442459106]

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
P = model.predict(X_predict)

true = 0
for i in range(X_predict.shape[0]):
    if(np.argmax(P[i]) == np.argmax(y_true[i])):
        true = true + 1

pre_accuracy = 100 * float(true/X_predict.shape[0])        
print('Predict Accuracy: {}' .format(pre_accuracy))
# Out:
# Predict Accuracy: 92.23643581826202

# %%
import seaborn as sns
false = len(X_predict) - true

predict = [true, false]
label = ['true_predict', 'false_predict']

plt.bar(label[0], predict[0])
plt.bar(label[1], predict[1])
plt.title('Predict Accuracy')
plt.xlabel('predict')
plt.ylabel('count')
plt.legend(['true_predict', 'false_predict'], loc='upper left')
plt.show()
